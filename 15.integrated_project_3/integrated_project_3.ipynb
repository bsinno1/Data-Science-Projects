# %% [markdown]
# # Project Description
#
# This data analysis project uses machine learning and data balancing techniques to create a predictive model higher than the target AUC-ROC (0.93 versus goal of > 0.88).
#
# # Project Overview
#
# Interconnect provides landline communication, internet, and several complimentary services.
# Clients select a monthly payment or yearly contracts.
# Interconnect wants a model for predicting the churn of clientele.
# If a user is forecast to leave, they will be offered promotional codes and special plan options.
# Data Description
#
# Data is valid as of February 1, 2020.
# Four data files from different souces are provided.
# contract.csv - contract information
# personal.csv - the client's personal data
# internet.csv - information about Interenet services
# phone.csv - information about telephone services
# The files are linked by the customerID column which contains a unique code assigned to each client.
# The target feature is the EndDate column equal to No.
# Project Goal
#
# Create a classification model that predicts if a customer will leave soon based on the data files supplied.
# AUC-ROC is the primary metric and needs to be at least 0.81, though greater than or equal to 0.88 is ideal.
# Accuracy will also be reported.

# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import datetime as dt
from datetime import date

#%pip install dexplot
import dexplot as dxp
import time
import matplotlib.ticker as ticker

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler as ss, OrdinalEncoder
from sklearn.metrics import *
from sklearn.model_selection import *
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier, CatBoostRegressor, Pool

# %% [markdown]
# # Import data

# %%
try:
    contract = pd.read_csv('contract.csv')
    internet = pd.read_csv('internet.csv')
    personal = pd.read_csv('personal.csv')
    phone = pd.read_csv('phone.csv')
except:
    contract = pd.read_csv('/datasets/final_provider/contract.csv') 
    personal = pd.read_csv('/datasets/final_provider/personal.csv') 
    internet = pd.read_csv('/datasets/final_provider/internet.csv') 
    phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %%
for file, df in zip(['contract', 'personal', 'internet', 'phone'], [contract, personal, internet, phone]):
    print(f'Shape of {file} is {df.shape}')
# Out:
# Shape of contract is (7043, 8)
# Shape of personal is (7043, 5)
# Shape of internet is (5517, 8)
# Shape of phone is (6361, 2)

# %% [markdown]
# Dataframes Internet and phone could indicate missing values in the final merged dataframe. These values could be a missing product for the customer_id.

# %%
for file, df in zip(['contract', 'personal', 'internet', 'phone'], [contract, personal, internet, phone]):
    print(f' First few rows of the {file} dataframe \n {df.head()}')
# Out:
#  First few rows of the contract dataframe
#     customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#  First few rows of the personal dataframe
#     customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
#  First few rows of the internet dataframe
#     customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No
#  First few rows of the phone dataframe
#     customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %% [markdown]
# Potential for creating more meaningful variables by combining begin and end dates: (1) number of active months, and (2) is_churned, and by creating a number of products variable. Encode dichotomous variables.

# %%
for file, df in zip(['contract', 'personal', 'internet', 'phone'], [contract, personal, internet, phone]):
    print(f'Pattern of missingness for {file} \n {df.isnull().sum()}')
# Out:
# Pattern of missingness for contract
#  customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64
# Pattern of missingness for personal
#  customerID       0
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# dtype: int64
# Pattern of missingness for internet
#  customerID          0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64
# Pattern of missingness for phone
#  customerID       0
# MultipleLines    0
# dtype: int64

# %% [markdown]
# The individual dataframes do not have missing values

# %%
for file, df in zip(['contract', 'personal', 'internet', 'phone'], [contract, personal, internet, phone]):
    print(f' Type of variable in {file} \n {df.dtypes}')
# Out:
#  Type of variable in contract
#  customerID           object
# BeginDate            object
# EndDate              object
# Type                 object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# dtype: object
#  Type of variable in personal
#  customerID       object
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# dtype: object
#  Type of variable in internet
#  customerID          object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object
#  Type of variable in phone
#  customerID       object
# MultipleLines    object
# dtype: object

# %% [markdown]
# Change data types of: BeginDate, EndDate, TotalCharges

# %%
for file, df in zip(['contract', 'personal', 'internet', 'phone'], [contract, personal, internet, phone]):
    print(f'Sum of observation duplicates for the {file} dataframe is {df.duplicated().sum()}')
# Out:
# Sum of observation duplicates for the contract dataframe is 0
# Sum of observation duplicates for the personal dataframe is 0
# Sum of observation duplicates for the internet dataframe is 0
# Sum of observation duplicates for the phone dataframe is 0

# %% [markdown]
# Observations
#
# - The contract file has 7043 observations with no missing values, no duplicate rows.
#
# - There are several datatypes will need to be addressed.

# %% [markdown]
# # Merging the dataframes

# %%
df = personal.merge(contract, left_on=['customerID'], right_on=['customerID'], how='left')
df = df.merge(phone, left_on=['customerID'], right_on=['customerID'], how='left')
df = df.merge(internet, left_on=['customerID'], right_on=['customerID'], how='left')

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents   BeginDate EndDate  \
# 0  7590-VHVEG  Female              0     Yes         No  2020-01-01      No
# 1  5575-GNVDE    Male              0      No         No  2017-04-01      No
#
#              Type PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 0  Month-to-month              Yes  Electronic check           29.85
# 1        One year               No      Mailed check           56.95
#
#   TotalCharges MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0        29.85           NaN             DSL             No          Yes
# 1       1889.5            No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# 1              Yes          No          No              No

# %% [markdown]
# # Data Cleaning

# %%
columns = []
for name in df.columns.values:
    name = re.sub('([A-Z])', r' \1', name).lower().replace(' ', '_')[1:]
    columns.append(name)
df.columns = columns

# %%
df.isnull().sum()/df.shape[0] *100
# Out:
# ustomer_i_d           0.000000
# ender                 0.000000
# senior_citizen        0.000000
# partner               0.000000
# dependents            0.000000
# begin_date            0.000000
# end_date              0.000000
# type                  0.000000
# paperless_billing     0.000000
# payment_method        0.000000
# monthly_charges       0.000000
# total_charges         0.000000
# multiple_lines        9.683374
# internet_service     21.666903
# online_security      21.666903
# online_backup        21.666903
# device_protection    21.666903
# tech_support         21.666903
# streaming_t_v        21.666903
# streaming_movies     21.666903
# dtype: float64

# %%
df = df.rename(columns = {'ender':'gender', "ustomer_i_d": "customer_id", "streaming_t_v":"streaming_tv"})

# %% [markdown]
# Check the pattern of missingness of these variables.  It is assumed that these missing values exist because the customer did not subscribe to the service.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## For the missing data, we assume that the customer has not subscribed to this service

# %%
for col in ["online_security","online_backup","device_protection","tech_support",
            "streaming_tv","streaming_movies", "multiple_lines",
           "partner","dependents"]:
    df[col] = df[col].fillna("No").apply(lambda x: 0 if x == 'No' else 1)

# %%
df["internet_service"] = df["internet_service"].fillna("No Service")

# %%
df['total_charges'] = df['total_charges'].replace(" ", np.nan).astype(np.float64)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Create the target: Churn

# %%
df['end_date'].max(),df['end_date'].min()
# Out:
# ('No', '2019-10-01 00:00:00')

# %%
df['churn'] = df['end_date'].apply(lambda x: 0 if x == 'No' else 1)
df.churn.value_counts()/df.shape[0]
# Out:
# 0    0.73463
# 1    0.26537
# Name: churn, dtype: float64

# %% [markdown]
# ## For the date variables, change type and create new variable:
#
# days_of_service
#
# day
#
# month
#
# year

# %%
df['begin_date'] = pd.to_datetime(df['begin_date'], format='%Y-%m-%d')

# %%
df['begin_date'].max(), df['begin_date'].min()
# Out:
# (Timestamp('2020-02-01 00:00:00'), Timestamp('2013-10-01 00:00:00'))

# %%
final_date = pd.to_datetime('2020-02-02') 
#final_date_temp = pd.to_datetime('2020-02-01') # check
df['days_of_service'] = (final_date - df['begin_date']).dt.days

# %%
df['days_of_service'].min(), df['days_of_service'].max()
# Out:
# (1, 2315)

# %%
df['days_of_service'] = df['days_of_service'].astype(np.float64)

# %%
df['year'] = df['begin_date'].dt.year
df['month'] = df['begin_date'].dt.month
df['day_of_week'] = df['begin_date'].dt.dayofweek

# %%
df["end_date"] = df["end_date"].replace("No", 0)

# %%
df["end_date"].value_counts()
# Out:
# 0                      5174
# 2019-11-01 00:00:00     485
# 2019-12-01 00:00:00     466
# 2020-01-01 00:00:00     460
# 2019-10-01 00:00:00     458
# Name: end_date, dtype: int64

# %%
df['end_date'] = pd.to_datetime(df['end_date'], format='%Y-%m-%d') #, errors='coerce')

# %% [markdown]
# ## Create new variable: Services

# %%
services = ['paperless_billing', 'multiple_lines', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']
df['services'] = df[services].sum(axis=1).astype('int')
# Out:
# /var/folders/gk/hvqbhchj1fqfp9s9tq_k1rfr0000gp/T/ipykernel_14980/2885660360.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['services'] = df[services].sum(axis=1).astype('int')

# %% [markdown]
# ## Change type

# %%
df["total_charges"] = pd.to_numeric(df["total_charges"], errors="coerce").fillna(0.0)

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()/df.shape[0] *100
# Out:
# customer_id          0.0
# gender               0.0
# senior_citizen       0.0
# partner              0.0
# dependents           0.0
# begin_date           0.0
# end_date             0.0
# type                 0.0
# paperless_billing    0.0
# payment_method       0.0
# monthly_charges      0.0
# total_charges        0.0
# multiple_lines       0.0
# internet_service     0.0
# online_security      0.0
# online_backup        0.0
# device_protection    0.0
# tech_support         0.0
# streaming_tv         0.0
# streaming_movies     0.0
# churn                0.0
# days_of_service      0.0
# year                 0.0
# month                0.0
# day_of_week          0.0
# services             0.0
# dtype: float64

# %% [markdown]
# # EDA

# %%
sns.countplot(df["churn"]);
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_no_id = df.drop('customer_id', axis=1)

# %%
#sns.set(font_scale=1)
fig, axes =plt.subplots(2,3, figsize=(15,10), sharex=True)
axes = axes.flatten()
object_bol = df_no_id.dtypes == 'object'
for ax, catplot in zip(axes, df_no_id.dtypes[object_bol].index):
    sns.countplot(y=catplot, data=df, ax=ax,   hue = "churn")
plt.tight_layout()  
plt.show()

# %% [markdown]
# Observations
#
# - Churning seems associated with month-to-month type of contract, paperless billing, electronic checks type of payment and fiber optic internet service.

# %%
fig, axes =plt.subplots(4,4, figsize=(10,10), sharex=True)
axes = axes.flatten()
object_bol = df.dtypes == 'int'
for ax, catplot in zip(axes, df.dtypes[object_bol].index):
    sns.countplot(y=catplot, data=df, ax=ax, hue = "churn")
plt.tight_layout()  
plt.show()

# %%
dxp.count("month", data=df, split='churn', normalize = "month", size=1)
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/dexplot/_common_plot.py:156: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   self.data[name].cat.remove_unused_categories(inplace=True)

# %%
dxp.count("day_of_week", data=df, split='churn', normalize = "day_of_week", size=1)
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/dexplot/_common_plot.py:156: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   self.data[name].cat.remove_unused_categories(inplace=True)

# %%
dxp.count("year", data=df, split='churn', normalize = "year", size=1)
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/dexplot/_common_plot.py:156: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   self.data[name].cat.remove_unused_categories(inplace=True)

# %%
dxp.count("services", data=df, split='churn', normalize = "services", size=1)
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/dexplot/_common_plot.py:156: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   self.data[name].cat.remove_unused_categories(inplace=True)

# %%
df.groupby(["churn",  "year"], sort = True).agg({'customer_id': 'count'}).plot(
    kind='bar', figsize=(13, 3), fontsize=12)
plt.xticks(rotation=45)
plt.legend(fontsize=12);

# %%
df.groupby(["churn",  "year", "month"], sort = True).agg({'customer_id': 'count'}).plot(
    kind='bar',  figsize=(13, 3), fontsize=12)
plt.xticks(np.arange(0, 150, step=10))
plt.xticks(rotation=45)
plt.legend(fontsize=12)
plt.xlabel('"churn",  "year", "month"', fontsize=18)
plt.ylabel('count', fontsize=18);

# %% [markdown]
# Observations
#
# - Churning seems associated with no online sercurity, no backup support, no device protection and no tech support.
# - The last months of the year seem most associated with churning
# - Those customers with 1 to 3 services are most associated with churning
# - Churning has been increasing every year and reaches its peak in 2019, but then drops
# - Midweek (Wednesday and Thursday) and Saturdays are most associated with churning.
# - In short, the total number of customers that churned starts to increase in September 2017 and increases exponentially until October 2019 and then drops significantly.

# %%
fig, axes =plt.subplots(1,3, figsize=(10,5), sharex=True)
axes = axes.flatten()
object_bol = df.dtypes == 'float'

for ax, floatplot in zip(axes, df.dtypes[object_bol].index):
    sns.histplot(y=floatplot, data=df, ax=ax, hue = "churn")

plt.tight_layout()  
plt.show()

# %%
active = df[df['churn'] == 0]
churned = df[df['churn'] == 1]

# %%
df.groupby('churn')['monthly_charges'].describe()
# Out:
#         count       mean        std    min    25%     50%   75%     max
# churn
# 0      5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# 1      1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %%
dfa = active.groupby([ "year", "month"], sort = True).agg({'monthly_charges': 'sum'})
dfa.plot(kind='bar', fontsize=12, figsize=(15, 3))
plt.xticks(rotation=45)
plt.yticks(np.arange(0,30000, 5000)),
plt.xticks(np.arange(0, 80, step=12))
plt.legend(title='active', fontsize=12)
dfb = churned.groupby([ "year", "month"], sort = True).agg({'monthly_charges': 'sum'})
dfb.plot(kind='bar', figsize=(15, 3), fontsize=12)
plt.xticks(rotation=45)
plt.yticks(np.arange(0,30000, 5000)),
plt.xticks(np.arange(4, 80, step=12))
plt.legend(title='churned',fontsize=12);

# %%
df.groupby('churn')['total_charges'].describe()
# Out:
#         count         mean          std    min    25%       50%      75%  \
# churn
# 0      5174.0  2549.911442  2329.954215   0.00  572.9  1679.525  4262.85
# 1      1869.0  1531.796094  1890.822994  18.85  134.5   703.550  2331.30
#
#            max
# churn
# 0      8672.45
# 1      8684.80

# %%
dfa = active.groupby([ "year", "month"], sort = True).agg({'total_charges': 'sum'})
dfa.plot(kind='bar', fontsize=12, figsize=(15, 3))
plt.xticks(rotation=45)
plt.yticks(np.arange(0,2000000, 200000)),
plt.xticks(np.arange(0, 80, step=12))
plt.legend(title='active', fontsize=12)
dfb = churned.groupby([ "year", "month"], sort = True).agg({'total_charges': 'sum'})
dfb.plot(kind='bar', figsize=(15, 3), fontsize=12)
plt.xticks(rotation=45)
plt.yticks(np.arange(0,100000, 10000)),
plt.xticks(np.arange(4, 80, step=12))
plt.legend(title='churned',fontsize=12);

# %%
fig, ax = plt.subplots(figsize=(15, 3))
for target in [0, 1]:
    df[df['churn'] == target].groupby('begin_date')['monthly_charges'].mean().plot(label=target)
plt.legend(labels=['Not churned', 'churned'], fontsize = 12)
plt.xlabel('begin_date')
plt.ylabel('Monthly Charges')
plt.title('Trend of monthly mean charges', fontsize = 12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 3))
for target in [0, 1]:
    df[df['churn'] == target].groupby('begin_date')['monthly_charges'].std().plot(label=target)
plt.legend(labels=['Not churned', 'Churned'])
plt.xlabel('begin_date')
plt.ylabel('Monthly Charges')
plt.legend(loc='upper right', fontsize = 12)
plt.title('Trend of variance in monthly charges', fontsize = 12)
plt.show()

# %%
df.groupby('churn')['days_of_service'].describe()
# Out:
#         count         mean         std   min    25%     50%     75%     max
# churn
# 0      5174.0  1145.447236  733.897937   1.0  458.0  1158.0  1858.0  2192.0
# 1      1869.0   625.455324  595.910567  63.0  154.0   366.0   946.0  2315.0

# %%
df.groupby(["churn", "year",  "days_of_service"], sort = True).agg({'customer_id': 'count'}).plot(
    kind='bar', figsize=(15, 3), fontsize=12)
plt.xticks(np.arange(0, 150, step=10))
plt.xticks(rotation=45)
plt.legend(fontsize=12)
plt.xlabel('"churn",  "year", "days_of_service"', fontsize=18)
plt.ylabel('count', fontsize=18);

# %%
df.groupby(["churn", "year", "month", "days_of_service"], sort = True).agg({'customer_id': 'count'}).plot(
    kind='bar', figsize=(15, 3), fontsize=12)
plt.xticks(np.arange(0, 150, step=8))
plt.xticks(rotation=90)
plt.legend(fontsize=12)
plt.xlabel('"churn",  "year", "month","days_of_service"', fontsize=18)
plt.ylabel('count', fontsize=18);

# %% [markdown]
# Observations
#
# - The mean monthly charges of those who churned is around 18% higher than those customers who are still active.  This trend is evident in the line chart above.  Only in mid 2015 and 2017 these mean become equal.  This line seems a bit smoother for those who are still active indicating less variance in monthly charges.  In fact, the second line chart tackles this head-on and shows that in fact the monthly charges of those who churned are volatile.
# - The bulk of those who churned seems to increase as monthly charges increase.  In may 2019, churning increases gradually to reach a peak in September.
# - The mean total charges for those who churned is 40\% less that those who are still active.  Over time, the total charges of active accounts is decreasing.  However, the total charges of those who churned seem t be more volatile
# - Churning seems associated with overall lower days of service.  The mean days_of_service for those who churned is half that of those who are still active.  In mid 2018, there seems to be a spike in the days_of_service of those who churned.  Although this surge is attenuated, it does not go back to its pre 2018 levels.  In fact, this surge peaked in January 2019, but has since decreased.

# %% [markdown]
# # Preprocessing

# %%
df = df.drop(['customer_id', 
              'end_date', 'begin_date'], axis=1)

# %%
list_obj = (df.dtypes == 'object')
object_cols = list(list_obj[list_obj].index)

# %%
df = pd.get_dummies(df, drop_first=True, columns = object_cols)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.heatmap(df.corr()[["churn"]].sort_values(by="churn", ascending=False), vmin=-1, vmax=1,  annot=True, cmap='Blues')
ax.set(title="Heatmap for " + "churn");

# %%
corr_df = df.corr()
corr_df.iloc[corr_df['churn'].abs().argsort()]["churn"]
# Out:
# gender_Male                              -0.008612
# day_of_week                               0.026492
# multiple_lines                            0.040102
# streaming_movies                          0.061382
# streaming_tv                              0.063228
# device_protection                        -0.066160
# services                                 -0.069533
# online_backup                            -0.082255
# payment_method_Mailed check              -0.091683
# payment_method_Credit card (automatic)   -0.134302
# partner                                  -0.150448
# senior_citizen                            0.150889
# dependents                               -0.164221
# tech_support                             -0.164674
# online_security                          -0.171226
# type_One year                            -0.177820
# month                                     0.181417
# paperless_billing_Yes                     0.191825
# monthly_charges                           0.193356
# total_charges                            -0.198324
# internet_service_No Service              -0.227890
# year                                      0.291621
# payment_method_Electronic check           0.301919
# type_Two year                            -0.302253
# internet_service_Fiber optic              0.308020
# days_of_service                          -0.311715
# churn                                     1.000000
# Name: churn, dtype: float64

# %% [markdown]
# Observations
#
# - For a first glance, the following variables seems important and correlated with the target:
#
# (1) days_of_service,
#
# (2) internet_service_Fiber_optic,
#
# (3) type_Two_year,
#
# (4) payment_method_Electronic check
#
# (5) year,
#
# (6) internet_service_No_Service,
#
# (7) total_charges,
#
# (8) monthly_charges,
#
# (9) paperless_billing_Yes,
#
# (10) month

# %%
# create feature and target variables 
target = df['churn']
features = df.drop(['churn'], axis=1)

# %%
# divide data with OHE into 3 groups using 3:1:1 (60%, 20%, 20%) ratio
X_train, X_valid, y_train, y_valid = train_test_split(
    features, target, test_size=0.4, random_state = 12345)
X_valid, X_test, y_valid, y_test = train_test_split(
    X_valid, y_valid, test_size=0.5, shuffle = False, random_state=12345)
print('Train target and features and percentage\n', y_train.shape, X_train.shape,
      'pct', (len(y_train)/len(df)))
print('Valid target and features and percentage\n', y_valid.shape, X_valid.shape,
      'pct', (len(y_valid)/len(df)))
print('Test target and features and percentage\n', y_test.shape, X_test.shape,
      'pct', (len(y_test)/len(df)))
# Out:
# Train target and features and percentage
#  (4225,) (4225, 26) pct 0.5998864120403238
# Valid target and features and percentage
#  (1409,) (1409, 26) pct 0.20005679397983814
# Test target and features and percentage
#  (1409,) (1409, 26) pct 0.20005679397983814

# %%
sc = ss()
X_train_scaled = sc.fit_transform(X_train)
X_valid_scaled = sc.transform(X_valid)
X_test_scaled = sc.transform(X_test)

# %%
X_train = pd.DataFrame(data=X_train_scaled,
                        index=X_train.index,    
                        columns=X_train.columns)

# %%
X_valid = pd.DataFrame(data=X_valid_scaled,
                        index=X_valid.index,    
                        columns=X_valid.columns)

# %%
X_test = pd.DataFrame(data=X_test_scaled,
                        index=X_test.index,    
                        columns=X_test.columns)

# %% [markdown]
# # Building the models

# %%
def build_model(model, train_X, train_y, valid_X, valid_y, 
                hyperparameters={}, 
                scoring=None, cv=5, model_str=None, cat_features=[], 
                early_stopping_rounds=50, verbose=False):
    """
    Build model
    """
    np.random.seed(42)
    best_score = 0
    start_time = time.time()
    
    if model_str == 'dummy':
        model.fit(train_X, train_y)
        preds = model.predict_proba(train_X)[:, 1]
        best_score = roc_auc_score(train_y, preds)
        return model, best_score, np.round(time.time() - start_time, 2)
    gs = GridSearchCV(model, param_grid=hyperparameters, cv=cv, scoring=scoring)
    gs.fit(train_X, train_y)
    if model_str == 'cat':
        gs.best_estimator_.fit(train_X, train_y, cat_features=cat_features, verbose=verbose)
    else:
        gs.best_estimator_.fit(train_X, train_y)
    preds = gs.best_estimator_.predict_proba(valid_X)[:, 1]
    best_score = roc_auc_score(valid_y, preds)
    end_time = time.time() - start_time
    return gs.best_estimator_, best_score, np.round(end_time, 2)

# %%
def roc_auc_scorer(y_true, y_pred):
    """
    Use the customer scorer for roc_auc_score
    inside GridSearch
    """
    return roc_auc_score(y_true, y_pred)

# %%
def display_classification_report(y_valid, y_pred):
    display(pd.DataFrame(classification_report(y_valid, y_pred, output_dict=True)).T)

# %%
def evaluate_model(model, train_features, train_target, test_features, test_target):
    
    eval_stats = {}
    
    fig, ax = plt.subplots(figsize=(10, 6)) 
    
    for type, features, target in (('train', train_features, train_target), ('test', test_features, test_target)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        
        # ROC
        fpr, tpr, roc_thresholds = roc_curve(target, pred_proba)
        roc_auc = roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # ROC
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'ROC Curve')
        
        
        eval_stats[type]['Accuracy'] = accuracy_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Accuracy', 'ROC AUC'))
    
    print(df_eval_stats)
    
    return df_eval_stats

# %%
dc = DummyClassifier()
best_dc_model, best_dc_auc, best_dc_time  = build_model(dc, X_train, y_train, 
                                                        X_valid, y_valid,
                                                        hyperparameters={}, 
                scoring=make_scorer(roc_auc_scorer, 
                                    needs_threshold=True,
                                    ), cv=2, model_str='dummy')
y_pred = dc.predict(X_valid)
display_classification_report(y_valid, y_pred)

result = evaluate_model(dc, X_train, y_train, X_valid, y_valid);
# Out:
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Rhea/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score      support
# 0              0.731015  1.000000  0.844608  1030.000000
# 1              0.000000  0.000000  0.000000   379.000000
# accuracy       0.731015  0.731015  0.731015     0.731015
# macro avg      0.365507  0.500000  0.422304  1409.000000
# weighted avg   0.534383  0.731015  0.617421  1409.000000
#           train  test
# Accuracy   0.74  0.73
# ROC AUC    0.50  0.50

# %%
lr = LogisticRegression(class_weight='balanced', random_state=42)
best_lr_model, best_lr_auc, best_lr_time = build_model(lr, X_train, y_train, 
                                                        X_valid, y_valid,
                                                        hyperparameters={'C' : [.001, .01, .1, 1, 10]}, 
                scoring=make_scorer(roc_auc_scorer, 
                                    needs_threshold=True,
                                    ), cv=5)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_valid)


print("The confusion matrix is", confusion_matrix(y_valid, y_pred))

display_classification_report(y_valid, y_pred)
result = evaluate_model(lr, X_train, y_train, X_valid, y_valid);
# Out:
# The confusion matrix is [[763 267]
#  [ 81 298]]
#               precision    recall  f1-score      support
# 0              0.904028  0.740777  0.814301  1030.000000
# 1              0.527434  0.786280  0.631356   379.000000
# accuracy       0.753016  0.753016  0.753016     0.753016
# macro avg      0.715731  0.763528  0.722828  1409.000000
# weighted avg   0.802730  0.753016  0.765091  1409.000000
#           train  test
# Accuracy   0.76  0.75
# ROC AUC    0.85  0.85

# %%
rf = RandomForestClassifier(class_weight='balanced', random_state=42)
best_rf_model, best_rf_auc, best_rf_time  = build_model(rf, X_train, y_train, 
                                                        X_valid, y_valid,
                                                        hyperparameters={'n_estimators': range(100, 600, 100),
                                                                        'max_depth': range(5, 10)
                                                                        }, 
                scoring=make_scorer(roc_auc_scorer, 
                                    needs_threshold=True,
                                    ), cv=5)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_valid)

print("The confusion matrix is", confusion_matrix(y_valid, y_pred))

display_classification_report(y_valid, y_pred)
result = evaluate_model(rf, X_train, y_train, X_valid, y_valid);
# Out:
# The confusion matrix is [[993  37]
#  [162 217]]
#               precision    recall  f1-score      support
# 0              0.859740  0.964078  0.908924  1030.000000
# 1              0.854331  0.572559  0.685624   379.000000
# accuracy       0.858765  0.858765  0.858765     0.858765
# macro avg      0.857035  0.768319  0.797274  1409.000000
# weighted avg   0.858285  0.858765  0.848860  1409.000000
#           train  test
# Accuracy    1.0  0.86
# ROC AUC     1.0  0.89

# %%
cat_features = X_train.select_dtypes(include=[np.uint8]).columns
cat = CatBoostClassifier(learning_rate=0.2, loss_function='Logloss',
                        random_seed=42)
best_cb_model, best_cb_auc, best_cb_time = build_model(cat, X_train, y_train, 
                                                        X_valid, y_valid,
                                                        hyperparameters={'iterations': range(100, 600, 100)}, 
                scoring=make_scorer(roc_auc_scorer, 
                                    needs_threshold=True,
                                    ), cv=5, model_str='catboost',
           cat_features=cat_features)

cat.fit(X_train, y_train)
y_pred = cat.predict(X_valid)

print("The confusion matrix is", confusion_matrix(y_valid, y_pred))


display_classification_report(y_valid, y_pred)
result = evaluate_model(cat, X_train, y_train, X_valid, y_valid);
# Out:
# 0:	learn: 0.5791299	total: 95ms	remaining: 9.4s
# 1:	learn: 0.5207276	total: 100ms	remaining: 4.91s
# 2:	learn: 0.4713883	total: 103ms	remaining: 3.32s
# 3:	learn: 0.4336783	total: 105ms	remaining: 2.52s
# 4:	learn: 0.4131625	total: 107ms	remaining: 2.03s
# 5:	learn: 0.4030921	total: 109ms	remaining: 1.7s
# 6:	learn: 0.3896614	total: 110ms	remaining: 1.47s
# 7:	learn: 0.3822292	total: 112ms	remaining: 1.29s
# 8:	learn: 0.3756249	total: 114ms	remaining: 1.15s
# 9:	learn: 0.3694965	total: 115ms	remaining: 1.04s
# 10:	learn: 0.3638205	total: 117ms	remaining: 945ms
# 11:	learn: 0.3585078	total: 118ms	remaining: 867ms
# 12:	learn: 0.3524340	total: 120ms	remaining: 802ms
# 13:	learn: 0.3493282	total: 121ms	remaining: 744ms
# 14:	learn: 0.3469076	total: 123ms	remaining: 696ms
# 15:	learn: 0.3410394	total: 124ms	remaining: 652ms
# 16:	learn: 0.3369658	total: 126ms	remaining: 614ms
# 17:	learn: 0.3317469	total: 127ms	remaining: 580ms
# 18:	learn: 0.3303570	total: 129ms	remaining: 549ms
# 19:	learn: 0.3270364	total: 130ms	remaining: 521ms
# 20:	learn: 0.3233562	total: 132ms	remaining: 496ms
# 21:	learn: 0.3199409	total: 133ms	remaining: 473ms
# 22:	learn: 0.3176706	total: 135ms	remaining: 452ms
# 23:	learn: 0.3157491	total: 136ms	remaining: 432ms
# 24:	learn: 0.3134361	total: 138ms	remaining: 414ms
# 25:	learn: 0.3098592	total: 140ms	remaining: 398ms
# 26:	learn: 0.3094539	total: 141ms	remaining: 380ms
# 27:	learn: 0.3060431	total: 142ms	remaining: 365ms
# 28:	learn: 0.3045785	total: 144ms	remaining: 352ms
# 29:	learn: 0.3033306	total: 145ms	remaining: 339ms
# 30:	learn: 0.3000724	total: 147ms	remaining: 327ms
# 31:	learn: 0.2979426	total: 149ms	remaining: 316ms
# 32:	learn: 0.2946250	total: 150ms	remaining: 305ms
# 33:	learn: 0.2932233	total: 152ms	remaining: 295ms
# 34:	learn: 0.2914317	total: 154ms	remaining: 285ms
# 35:	learn: 0.2890626	total: 155ms	remaining: 276ms
# 36:	learn: 0.2863879	total: 157ms	remaining: 267ms
# 37:	learn: 0.2835300	total: 158ms	remaining: 258ms
# 38:	learn: 0.2812168	total: 160ms	remaining: 250ms
# 39:	learn: 0.2787677	total: 161ms	remaining: 242ms
# 40:	learn: 0.2762505	total: 163ms	remaining: 234ms
# 41:	learn: 0.2736888	total: 165ms	remaining: 227ms
# 42:	learn: 0.2710822	total: 166ms	remaining: 221ms
# 43:	learn: 0.2692111	total: 168ms	remaining: 214ms
# 44:	learn: 0.2675139	total: 169ms	remaining: 207ms
# 45:	learn: 0.2649031	total: 171ms	remaining: 201ms
# 46:	learn: 0.2626140	total: 172ms	remaining: 194ms
# 47:	learn: 0.2602760	total: 174ms	remaining: 189ms
# 48:	learn: 0.2576763	total: 176ms	remaining: 183ms
# 49:	learn: 0.2552430	total: 177ms	remaining: 177ms
# 50:	learn: 0.2534827	total: 179ms	remaining: 172ms
# 51:	learn: 0.2504436	total: 180ms	remaining: 166ms
# 52:	learn: 0.2477247	total: 182ms	remaining: 161ms
# 53:	learn: 0.2450200	total: 183ms	remaining: 156ms
# 54:	learn: 0.2430919	total: 185ms	remaining: 151ms
# 55:	learn: 0.2413671	total: 186ms	remaining: 147ms
# 56:	learn: 0.2390847	total: 188ms	remaining: 142ms
# 57:	learn: 0.2357393	total: 190ms	remaining: 137ms
# 58:	learn: 0.2336434	total: 192ms	remaining: 133ms
# 59:	learn: 0.2306002	total: 193ms	remaining: 129ms
# 60:	learn: 0.2292586	total: 195ms	remaining: 125ms
# 61:	learn: 0.2280247	total: 196ms	remaining: 120ms
# 62:	learn: 0.2267604	total: 198ms	remaining: 116ms
# 63:	learn: 0.2242237	total: 199ms	remaining: 112ms
# 64:	learn: 0.2225064	total: 201ms	remaining: 108ms
# 65:	learn: 0.2212310	total: 202ms	remaining: 104ms
# 66:	learn: 0.2188334	total: 204ms	remaining: 100ms
# 67:	learn: 0.2174631	total: 205ms	remaining: 96.6ms
# 68:	learn: 0.2154755	total: 207ms	remaining: 93ms
# 69:	learn: 0.2134218	total: 208ms	remaining: 89.3ms
# 70:	learn: 0.2117633	total: 210ms	remaining: 85.7ms
# 71:	learn: 0.2090885	total: 212ms	remaining: 82.3ms
# 72:	learn: 0.2070060	total: 213ms	remaining: 78.8ms
# 73:	learn: 0.2058861	total: 215ms	remaining: 75.5ms
# 74:	learn: 0.2038223	total: 216ms	remaining: 72.1ms
# 75:	learn: 0.2015524	total: 218ms	remaining: 68.8ms
# 76:	learn: 0.2004019	total: 219ms	remaining: 65.5ms
# 77:	learn: 0.1986275	total: 221ms	remaining: 62.3ms
# 78:	learn: 0.1969200	total: 222ms	remaining: 59.1ms
# 79:	learn: 0.1954314	total: 224ms	remaining: 56ms
# 80:	learn: 0.1937825	total: 226ms	remaining: 53ms
# 81:	learn: 0.1929193	total: 227ms	remaining: 49.9ms
# 82:	learn: 0.1915122	total: 229ms	remaining: 46.8ms
# 83:	learn: 0.1901201	total: 230ms	remaining: 43.8ms
# 84:	learn: 0.1879107	total: 232ms	remaining: 40.9ms
# 85:	learn: 0.1855753	total: 233ms	remaining: 38ms
# 86:	learn: 0.1838457	total: 237ms	remaining: 35.4ms
# 87:	learn: 0.1818765	total: 239ms	remaining: 32.6ms
# 88:	learn: 0.1813884	total: 240ms	remaining: 29.7ms
# 89:	learn: 0.1795039	total: 242ms	remaining: 26.9ms
# 90:	learn: 0.1781665	total: 243ms	remaining: 24.1ms
# 91:	learn: 0.1766651	total: 245ms	remaining: 21.3ms
# 92:	learn: 0.1757410	total: 247ms	remaining: 18.6ms
# 93:	learn: 0.1745054	total: 248ms	remaining: 15.8ms
# 94:	learn: 0.1734108	total: 250ms	remaining: 13.1ms
# 95:	learn: 0.1723534	total: 251ms	remaining: 10.5ms
# 96:	learn: 0.1719684	total: 253ms	remaining: 7.81ms
# 97:	learn: 0.1704519	total: 254ms	remaining: 5.19ms
# 98:	learn: 0.1689909	total: 256ms	remaining: 2.58ms
# 99:	learn: 0.1674532	total: 258ms	remaining: 0us
# 0:	learn: 0.5795204	total: 1.42ms	remaining: 140ms
# 1:	learn: 0.5215347	total: 3.12ms	remaining: 153ms
# 2:	learn: 0.4735810	total: 4.73ms	remaining: 153ms
# 3:	learn: 0.4407544	total: 7.76ms	remaining: 186ms
# 4:	learn: 0.4189615	total: 9.89ms	remaining: 188ms
# 5:	learn: 0.4055978	total: 12.1ms	remaining: 190ms
# 6:	learn: 0.3878921	total: 16.5ms	remaining: 219ms
# 7:	learn: 0.3802208	total: 19.8ms	remaining: 228ms
# 8:	learn: 0.3742410	total: 22.5ms	remaining: 228ms
# 9:	learn: 0.3687338	total: 24ms	remaining: 216ms
# 10:	learn: 0.3648120	total: 25.5ms	remaining: 206ms
# 11:	learn: 0.3575011	total: 27ms	remaining: 198ms
# 12:	learn: 0.3538237	total: 28.7ms	remaining: 192ms
# 13:	learn: 0.3486212	total: 30.7ms	remaining: 189ms
# 14:	learn: 0.3456390	total: 32.5ms	remaining: 184ms
# 15:	learn: 0.3417505	total: 34.5ms	remaining: 181ms
# 16:	learn: 0.3390662	total: 36.3ms	remaining: 177ms
# 17:	learn: 0.3352784	total: 38.6ms	remaining: 176ms
# 18:	learn: 0.3299918	total: 41ms	remaining: 175ms
# 19:	learn: 0.3261824	total: 42.8ms	remaining: 171ms
# 20:	learn: 0.3229361	total: 46.1ms	remaining: 173ms
# 21:	learn: 0.3179023	total: 49.7ms	remaining: 176ms
# 22:	learn: 0.3146870	total: 51.5ms	remaining: 172ms
# 23:	learn: 0.3121669	total: 53ms	remaining: 168ms
# 24:	learn: 0.3098501	total: 54.5ms	remaining: 164ms
# 25:	learn: 0.3072211	total: 55.9ms	remaining: 159ms
# 26:	learn: 0.3068173	total: 56.9ms	remaining: 154ms
# 27:	learn: 0.3036407	total: 58.6ms	remaining: 151ms
# 28:	learn: 0.3015470	total: 60.3ms	remaining: 148ms
# 29:	learn: 0.2982686	total: 61.8ms	remaining: 144ms
# 30:	learn: 0.2953592	total: 64ms	remaining: 142ms
# 31:	learn: 0.2941025	total: 65.6ms	remaining: 140ms
# 32:	learn: 0.2906500	total: 67.2ms	remaining: 136ms
# 33:	learn: 0.2877310	total: 68.7ms	remaining: 133ms
# 34:	learn: 0.2848586	total: 70.3ms	remaining: 130ms
# 35:	learn: 0.2824673	total: 72ms	remaining: 128ms
# 36:	learn: 0.2808686	total: 73.8ms	remaining: 126ms
# 37:	learn: 0.2768446	total: 75.3ms	remaining: 123ms
# 38:	learn: 0.2733409	total: 76.8ms	remaining: 120ms
# 39:	learn: 0.2709249	total: 78.6ms	remaining: 118ms
# 40:	learn: 0.2683762	total: 80.1ms	remaining: 115ms
# 41:	learn: 0.2656898	total: 81.5ms	remaining: 113ms
# 42:	learn: 0.2639689	total: 83.1ms	remaining: 110ms
# 43:	learn: 0.2627694	total: 84.6ms	remaining: 108ms
# 44:	learn: 0.2595168	total: 86.3ms	remaining: 105ms
# 45:	learn: 0.2567206	total: 87.8ms	remaining: 103ms
# 46:	learn: 0.2540903	total: 89.3ms	remaining: 101ms
# 47:	learn: 0.2516052	total: 90.9ms	remaining: 98.5ms
# 48:	learn: 0.2495976	total: 92.4ms	remaining: 96.1ms
# 49:	learn: 0.2471275	total: 93.9ms	remaining: 93.9ms
# 50:	learn: 0.2448467	total: 95.4ms	remaining: 91.7ms
# 51:	learn: 0.2429868	total: 97ms	remaining: 89.6ms
# 52:	learn: 0.2404678	total: 98.5ms	remaining: 87.3ms
# 53:	learn: 0.2389518	total: 100ms	remaining: 85.3ms
# 54:	learn: 0.2369897	total: 102ms	remaining: 83.2ms
# 55:	learn: 0.2343849	total: 103ms	remaining: 81.2ms
# 56:	learn: 0.2325000	total: 105ms	remaining: 79.2ms
# 57:	learn: 0.2307144	total: 107ms	remaining: 77.1ms
# 58:	learn: 0.2282102	total: 108ms	remaining: 75.1ms
# 59:	learn: 0.2262131	total: 110ms	remaining: 73.2ms
# 60:	learn: 0.2232095	total: 111ms	remaining: 71.1ms
# 61:	learn: 0.2207500	total: 113ms	remaining: 69.1ms
# 62:	learn: 0.2188537	total: 114ms	remaining: 67.2ms
# 63:	learn: 0.2171087	total: 116ms	remaining: 65.2ms
# 64:	learn: 0.2157065	total: 118ms	remaining: 63.4ms
# 65:	learn: 0.2135847	total: 119ms	remaining: 61.4ms
# 66:	learn: 0.2111268	total: 121ms	remaining: 59.5ms
# 67:	learn: 0.2094566	total: 122ms	remaining: 57.5ms
# 68:	learn: 0.2073387	total: 124ms	remaining: 55.5ms
# 69:	learn: 0.2062157	total: 125ms	remaining: 53.6ms
# 70:	learn: 0.2053879	total: 127ms	remaining: 51.8ms
# 71:	learn: 0.2032035	total: 128ms	remaining: 49.9ms
# 72:	learn: 0.2013815	total: 130ms	remaining: 48ms
# 73:	learn: 0.1996747	total: 131ms	remaining: 46.1ms
# 74:	learn: 0.1988314	total: 133ms	remaining: 44.5ms
# 75:	learn: 0.1965686	total: 135ms	remaining: 42.7ms
# 76:	learn: 0.1948784	total: 137ms	remaining: 40.8ms
# 77:	learn: 0.1934536	total: 138ms	remaining: 39ms
# 78:	learn: 0.1922882	total: 140ms	remaining: 37.1ms
# 79:	learn: 0.1912434	total: 141ms	remaining: 35.3ms
# 80:	learn: 0.1896919	total: 143ms	remaining: 33.5ms
# 81:	learn: 0.1883057	total: 145ms	remaining: 31.7ms
# 82:	learn: 0.1870083	total: 146ms	remaining: 29.9ms
# 83:	learn: 0.1851453	total: 147ms	remaining: 28.1ms
# 84:	learn: 0.1831772	total: 149ms	remaining: 26.3ms
# 85:	learn: 0.1822320	total: 150ms	remaining: 24.5ms
# 86:	learn: 0.1818789	total: 152ms	remaining: 22.7ms
# 87:	learn: 0.1804668	total: 153ms	remaining: 20.9ms
# 88:	learn: 0.1793659	total: 155ms	remaining: 19.1ms
# 89:	learn: 0.1770726	total: 157ms	remaining: 17.4ms
# 90:	learn: 0.1759298	total: 158ms	remaining: 15.6ms
# 91:	learn: 0.1747886	total: 160ms	remaining: 13.9ms
# 92:	learn: 0.1739441	total: 161ms	remaining: 12.1ms
# 93:	learn: 0.1724948	total: 162ms	remaining: 10.4ms
# 94:	learn: 0.1710584	total: 164ms	remaining: 8.63ms
# 95:	learn: 0.1701182	total: 165ms	remaining: 6.89ms
# 96:	learn: 0.1683425	total: 167ms	remaining: 5.16ms
# 97:	learn: 0.1671591	total: 169ms	remaining: 3.44ms
# 98:	learn: 0.1661071	total: 170ms	remaining: 1.72ms
# 99:	learn: 0.1648973	total: 171ms	remaining: 0us
# 0:	learn: 0.5805381	total: 2.02ms	remaining: 200ms
# 1:	learn: 0.5243898	total: 4.54ms	remaining: 222ms
# 2:	learn: 0.4702008	total: 7.71ms	remaining: 249ms
# 3:	learn: 0.4456770	total: 9.9ms	remaining: 238ms
# 4:	learn: 0.4248024	total: 12ms	remaining: 227ms
# 5:	learn: 0.4129254	total: 14.1ms	remaining: 220ms
# 6:	learn: 0.4001928	total: 16.9ms	remaining: 224ms
# 7:	learn: 0.3920261	total: 19ms	remaining: 218ms
# 8:	learn: 0.3821001	total: 22.5ms	remaining: 228ms
# 9:	learn: 0.3754033	total: 24.7ms	remaining: 222ms
# 10:	learn: 0.3722210	total: 26.7ms	remaining: 216ms
# 11:	learn: 0.3651385	total: 30.3ms	remaining: 222ms
# 12:	learn: 0.3595822	total: 32.3ms	remaining: 216ms
# 13:	learn: 0.3565160	total: 34.3ms	remaining: 211ms
# 14:	learn: 0.3527029	total: 36.9ms	remaining: 209ms
# 15:	learn: 0.3482731	total: 39.5ms	remaining: 207ms
# 16:	learn: 0.3454892	total: 42.2ms	remaining: 206ms
# 17:	learn: 0.3387587	total: 44.5ms	remaining: 203ms
# 18:	learn: 0.3337333	total: 47.1ms	remaining: 201ms
# 19:	learn: 0.3307931	total: 49.1ms	remaining: 197ms
# 20:	learn: 0.3275080	total: 51.7ms	remaining: 195ms
# 21:	learn: 0.3235341	total: 54ms	remaining: 192ms
# 22:	learn: 0.3221876	total: 56.1ms	remaining: 188ms
# 23:	learn: 0.3181937	total: 58.8ms	remaining: 186ms
# 24:	learn: 0.3172805	total: 61.4ms	remaining: 184ms
# 25:	learn: 0.3154383	total: 63.5ms	remaining: 181ms
# 26:	learn: 0.3151187	total: 66.5ms	remaining: 180ms
# 27:	learn: 0.3130428	total: 69.4ms	remaining: 178ms
# 28:	learn: 0.3107260	total: 73.1ms	remaining: 179ms
# 29:	learn: 0.3098062	total: 74.9ms	remaining: 175ms
# 30:	learn: 0.3065477	total: 76.7ms	remaining: 171ms
# 31:	learn: 0.3044230	total: 78.1ms	remaining: 166ms
# 32:	learn: 0.3003749	total: 79.6ms	remaining: 162ms
# 33:	learn: 0.2972037	total: 81.3ms	remaining: 158ms
# 34:	learn: 0.2944814	total: 82.9ms	remaining: 154ms
# 35:	learn: 0.2923689	total: 84.5ms	remaining: 150ms
# 36:	learn: 0.2901942	total: 86.6ms	remaining: 147ms
# 37:	learn: 0.2882105	total: 89.1ms	remaining: 145ms
# 38:	learn: 0.2851784	total: 91ms	remaining: 142ms
# 39:	learn: 0.2829151	total: 93ms	remaining: 139ms
# 40:	learn: 0.2794541	total: 94.9ms	remaining: 137ms
# 41:	learn: 0.2771586	total: 97.1ms	remaining: 134ms
# 42:	learn: 0.2741945	total: 99.5ms	remaining: 132ms
# 43:	learn: 0.2730056	total: 102ms	remaining: 130ms
# 44:	learn: 0.2704040	total: 104ms	remaining: 127ms
# 45:	learn: 0.2671865	total: 106ms	remaining: 124ms
# 46:	learn: 0.2639176	total: 107ms	remaining: 121ms
# 47:	learn: 0.2614463	total: 109ms	remaining: 118ms
# 48:	learn: 0.2586147	total: 111ms	remaining: 115ms
# 49:	learn: 0.2567091	total: 112ms	remaining: 112ms
# 50:	learn: 0.2541851	total: 114ms	remaining: 110ms
# 51:	learn: 0.2522077	total: 116ms	remaining: 107ms
# 52:	learn: 0.2489835	total: 117ms	remaining: 104ms
# 53:	learn: 0.2466906	total: 119ms	remaining: 101ms
# 54:	learn: 0.2455879	total: 120ms	remaining: 98.4ms
# 55:	learn: 0.2434608	total: 122ms	remaining: 95.8ms
# 56:	learn: 0.2421655	total: 124ms	remaining: 93.2ms
# 57:	learn: 0.2402047	total: 125ms	remaining: 90.8ms
# 58:	learn: 0.2376986	total: 127ms	remaining: 88.1ms
# 59:	learn: 0.2351803	total: 128ms	remaining: 85.5ms
# 60:	learn: 0.2328194	total: 130ms	remaining: 82.9ms
# 61:	learn: 0.2310002	total: 132ms	remaining: 80.7ms
# 62:	learn: 0.2282372	total: 133ms	remaining: 78.2ms
# 63:	learn: 0.2261686	total: 135ms	remaining: 75.7ms
# 64:	learn: 0.2240759	total: 136ms	remaining: 73.2ms
# 65:	learn: 0.2222306	total: 137ms	remaining: 70.8ms
# 66:	learn: 0.2198293	total: 139ms	remaining: 68.5ms
# 67:	learn: 0.2173344	total: 141ms	remaining: 66.2ms
# 68:	learn: 0.2155231	total: 142ms	remaining: 64ms
# 69:	learn: 0.2135382	total: 144ms	remaining: 61.7ms
# 70:	learn: 0.2115145	total: 145ms	remaining: 59.4ms
# 71:	learn: 0.2094528	total: 147ms	remaining: 57.2ms
# 72:	learn: 0.2069533	total: 149ms	remaining: 55.1ms
# 73:	learn: 0.2054917	total: 150ms	remaining: 52.9ms
# 74:	learn: 0.2041768	total: 152ms	remaining: 50.6ms
# 75:	learn: 0.2026181	total: 153ms	remaining: 48.4ms
# 76:	learn: 0.2004300	total: 155ms	remaining: 46.2ms
# 77:	learn: 0.1985305	total: 156ms	remaining: 44.1ms
# 78:	learn: 0.1973433	total: 158ms	remaining: 42ms
# 79:	learn: 0.1956864	total: 160ms	remaining: 39.9ms
# 80:	learn: 0.1941411	total: 161ms	remaining: 37.8ms
# 81:	learn: 0.1925038	total: 163ms	remaining: 35.7ms
# 82:	learn: 0.1916868	total: 164ms	remaining: 33.6ms
# 83:	learn: 0.1902952	total: 166ms	remaining: 31.6ms
# 84:	learn: 0.1883893	total: 167ms	remaining: 29.5ms
# 85:	learn: 0.1867255	total: 169ms	remaining: 27.4ms
# 86:	learn: 0.1849803	total: 170ms	remaining: 25.4ms
# 87:	learn: 0.1835882	total: 171ms	remaining: 23.4ms
# 88:	learn: 0.1824602	total: 173ms	remaining: 21.4ms
# 89:	learn: 0.1818867	total: 174ms	remaining: 19.4ms
# 90:	learn: 0.1800846	total: 176ms	remaining: 17.4ms
# 91:	learn: 0.1784510	total: 177ms	remaining: 15.4ms
# 92:	learn: 0.1772291	total: 179ms	remaining: 13.5ms
# 93:	learn: 0.1757059	total: 180ms	remaining: 11.5ms
# 94:	learn: 0.1746501	total: 182ms	remaining: 9.57ms
# 95:	learn: 0.1734848	total: 184ms	remaining: 7.66ms
# 96:	learn: 0.1723202	total: 186ms	remaining: 5.75ms
# 97:	learn: 0.1707586	total: 188ms	remaining: 3.84ms
# 98:	learn: 0.1694511	total: 190ms	remaining: 1.92ms
# 99:	learn: 0.1682852	total: 192ms	remaining: 0us
# 0:	learn: 0.5785100	total: 1.55ms	remaining: 154ms
# 1:	learn: 0.5208581	total: 3.02ms	remaining: 148ms
# 2:	learn: 0.4674945	total: 4.69ms	remaining: 152ms
# 3:	learn: 0.4359858	total: 7.11ms	remaining: 171ms
# 4:	learn: 0.4199547	total: 9.55ms	remaining: 182ms
# 5:	learn: 0.4080897	total: 13.1ms	remaining: 205ms
# 6:	learn: 0.3940382	total: 14.8ms	remaining: 196ms
# 7:	learn: 0.3878570	total: 16.5ms	remaining: 190ms
# 8:	learn: 0.3820363	total: 18.2ms	remaining: 184ms
# 9:	learn: 0.3763546	total: 20.2ms	remaining: 182ms
# 10:	learn: 0.3726928	total: 22.2ms	remaining: 180ms
# 11:	learn: 0.3591940	total: 24.7ms	remaining: 181ms
# 12:	learn: 0.3556293	total: 26.9ms	remaining: 180ms
# 13:	learn: 0.3536920	total: 28.3ms	remaining: 174ms
# 14:	learn: 0.3504750	total: 29.7ms	remaining: 168ms
# 15:	learn: 0.3476591	total: 31.2ms	remaining: 164ms
# 16:	learn: 0.3429195	total: 32.8ms	remaining: 160ms
# 17:	learn: 0.3375713	total: 34.2ms	remaining: 156ms
# 18:	learn: 0.3332594	total: 35.7ms	remaining: 152ms
# 19:	learn: 0.3295111	total: 37.6ms	remaining: 150ms
# 20:	learn: 0.3261115	total: 39.3ms	remaining: 148ms
# 21:	learn: 0.3230251	total: 40.9ms	remaining: 145ms
# 22:	learn: 0.3201938	total: 42.3ms	remaining: 142ms
# 23:	learn: 0.3167773	total: 43.7ms	remaining: 138ms
# 24:	learn: 0.3149175	total: 45.2ms	remaining: 135ms
# 25:	learn: 0.3120839	total: 46.6ms	remaining: 133ms
# 26:	learn: 0.3099627	total: 48.2ms	remaining: 130ms
# 27:	learn: 0.3073314	total: 49.8ms	remaining: 128ms
# 28:	learn: 0.3040332	total: 51.3ms	remaining: 125ms
# 29:	learn: 0.3020798	total: 53.1ms	remaining: 124ms
# 30:	learn: 0.2996004	total: 54.6ms	remaining: 122ms
# 31:	learn: 0.2967828	total: 56.1ms	remaining: 119ms
# 32:	learn: 0.2943228	total: 58ms	remaining: 118ms
# 33:	learn: 0.2920831	total: 59.4ms	remaining: 115ms
# 34:	learn: 0.2902140	total: 61.1ms	remaining: 114ms
# 35:	learn: 0.2872336	total: 62.6ms	remaining: 111ms
# 36:	learn: 0.2859711	total: 64.2ms	remaining: 109ms
# 37:	learn: 0.2825364	total: 65.8ms	remaining: 107ms
# 38:	learn: 0.2817283	total: 67ms	remaining: 105ms
# 39:	learn: 0.2802746	total: 68.6ms	remaining: 103ms
# 40:	learn: 0.2777838	total: 70.3ms	remaining: 101ms
# 41:	learn: 0.2748660	total: 73.2ms	remaining: 101ms
# 42:	learn: 0.2712678	total: 74.7ms	remaining: 99.1ms
# 43:	learn: 0.2691317	total: 76.1ms	remaining: 96.9ms
# 44:	learn: 0.2671330	total: 77.8ms	remaining: 95.1ms
# 45:	learn: 0.2646727	total: 79.2ms	remaining: 93ms
# 46:	learn: 0.2618168	total: 80.7ms	remaining: 91.1ms
# 47:	learn: 0.2590729	total: 82.5ms	remaining: 89.4ms
# 48:	learn: 0.2569579	total: 84.1ms	remaining: 87.5ms
# 49:	learn: 0.2555097	total: 85.5ms	remaining: 85.5ms
# 50:	learn: 0.2538835	total: 87ms	remaining: 83.6ms
# 51:	learn: 0.2508183	total: 88.5ms	remaining: 81.7ms
# 52:	learn: 0.2492110	total: 90ms	remaining: 79.8ms
# 53:	learn: 0.2464424	total: 91.5ms	remaining: 77.9ms
# 54:	learn: 0.2435262	total: 93.1ms	remaining: 76.2ms
# 55:	learn: 0.2413564	total: 94.7ms	remaining: 74.4ms
# 56:	learn: 0.2384765	total: 96.2ms	remaining: 72.6ms
# 57:	learn: 0.2363034	total: 97.6ms	remaining: 70.7ms
# 58:	learn: 0.2340662	total: 99.1ms	remaining: 68.8ms
# 59:	learn: 0.2323479	total: 101ms	remaining: 67.2ms
# 60:	learn: 0.2304160	total: 102ms	remaining: 65.4ms
# 61:	learn: 0.2280206	total: 104ms	remaining: 63.7ms
# 62:	learn: 0.2265559	total: 106ms	remaining: 62ms
# 63:	learn: 0.2242107	total: 107ms	remaining: 60.2ms
# 64:	learn: 0.2223848	total: 109ms	remaining: 58.5ms
# 65:	learn: 0.2206527	total: 110ms	remaining: 56.7ms
# 66:	learn: 0.2182435	total: 112ms	remaining: 55.1ms
# 67:	learn: 0.2162640	total: 114ms	remaining: 53.4ms
# 68:	learn: 0.2136682	total: 115ms	remaining: 51.7ms
# 69:	learn: 0.2123215	total: 117ms	remaining: 50.1ms
# 70:	learn: 0.2107604	total: 118ms	remaining: 48.4ms
# 71:	learn: 0.2088168	total: 120ms	remaining: 46.6ms
# 72:	learn: 0.2072389	total: 121ms	remaining: 44.9ms
# 73:	learn: 0.2056736	total: 123ms	remaining: 43.2ms
# 74:	learn: 0.2042485	total: 125ms	remaining: 41.5ms
# 75:	learn: 0.2026804	total: 126ms	remaining: 39.8ms
# 76:	learn: 0.2014011	total: 128ms	remaining: 38.1ms
# 77:	learn: 0.2000678	total: 129ms	remaining: 36.4ms
# 78:	learn: 0.1987070	total: 131ms	remaining: 34.7ms
# 79:	learn: 0.1971270	total: 132ms	remaining: 33.1ms
# 80:	learn: 0.1955308	total: 134ms	remaining: 31.4ms
# 81:	learn: 0.1936454	total: 135ms	remaining: 29.7ms
# 82:	learn: 0.1921234	total: 137ms	remaining: 28ms
# 83:	learn: 0.1907358	total: 138ms	remaining: 26.3ms
# 84:	learn: 0.1889408	total: 140ms	remaining: 24.7ms
# 85:	learn: 0.1880142	total: 141ms	remaining: 23ms
# 86:	learn: 0.1865131	total: 143ms	remaining: 21.4ms
# 87:	learn: 0.1854989	total: 145ms	remaining: 19.7ms
# 88:	learn: 0.1836471	total: 146ms	remaining: 18.1ms
# 89:	learn: 0.1819919	total: 148ms	remaining: 16.4ms
# 90:	learn: 0.1803609	total: 149ms	remaining: 14.7ms
# 91:	learn: 0.1790016	total: 151ms	remaining: 13.1ms
# 92:	learn: 0.1774405	total: 152ms	remaining: 11.4ms
# 93:	learn: 0.1759668	total: 154ms	remaining: 9.8ms
# 94:	learn: 0.1745586	total: 155ms	remaining: 8.17ms
# 95:	learn: 0.1729158	total: 157ms	remaining: 6.53ms
# 96:	learn: 0.1720790	total: 158ms	remaining: 4.89ms
# 97:	learn: 0.1707259	total: 160ms	remaining: 3.26ms
# 98:	learn: 0.1700198	total: 162ms	remaining: 1.64ms
# 99:	learn: 0.1689746	total: 165ms	remaining: 0us
# 0:	learn: 0.5747670	total: 1.87ms	remaining: 186ms
# 1:	learn: 0.5133801	total: 3.71ms	remaining: 182ms
# 2:	learn: 0.4607389	total: 5.63ms	remaining: 182ms
# 3:	learn: 0.4328943	total: 7.96ms	remaining: 191ms
# 4:	learn: 0.4112102	total: 10.3ms	remaining: 196ms
# 5:	learn: 0.3975467	total: 12.6ms	remaining: 198ms
# 6:	learn: 0.3870404	total: 14.8ms	remaining: 196ms
# 7:	learn: 0.3799706	total: 16.9ms	remaining: 194ms
# 8:	learn: 0.3736175	total: 19ms	remaining: 193ms
# 9:	learn: 0.3656449	total: 21.2ms	remaining: 191ms
# 10:	learn: 0.3619094	total: 23ms	remaining: 186ms
# 11:	learn: 0.3484041	total: 24.5ms	remaining: 180ms
# 12:	learn: 0.3449343	total: 26.1ms	remaining: 175ms
# 13:	learn: 0.3433117	total: 27.7ms	remaining: 170ms
# 14:	learn: 0.3404251	total: 29.7ms	remaining: 168ms
# 15:	learn: 0.3374624	total: 31.7ms	remaining: 167ms
# 16:	learn: 0.3343196	total: 33.5ms	remaining: 163ms
# 17:	learn: 0.3292121	total: 35.4ms	remaining: 161ms
# 18:	learn: 0.3259185	total: 38.1ms	remaining: 162ms
# 19:	learn: 0.3227641	total: 39.7ms	remaining: 159ms
# 20:	learn: 0.3195049	total: 41ms	remaining: 154ms
# 21:	learn: 0.3167841	total: 42.5ms	remaining: 151ms
# 22:	learn: 0.3152486	total: 43.8ms	remaining: 146ms
# 23:	learn: 0.3105758	total: 45.3ms	remaining: 143ms
# 24:	learn: 0.3081266	total: 47.1ms	remaining: 141ms
# 25:	learn: 0.3047480	total: 48.6ms	remaining: 138ms
# 26:	learn: 0.3021640	total: 50ms	remaining: 135ms
# 27:	learn: 0.3003795	total: 51.6ms	remaining: 133ms
# 28:	learn: 0.2968281	total: 53.1ms	remaining: 130ms
# 29:	learn: 0.2944844	total: 54.6ms	remaining: 127ms
# 30:	learn: 0.2917862	total: 56ms	remaining: 125ms
# 31:	learn: 0.2891412	total: 57.4ms	remaining: 122ms
# 32:	learn: 0.2872912	total: 58.9ms	remaining: 120ms
# 33:	learn: 0.2854325	total: 60.4ms	remaining: 117ms
# 34:	learn: 0.2825384	total: 61.9ms	remaining: 115ms
# 35:	learn: 0.2800179	total: 63.4ms	remaining: 113ms
# 36:	learn: 0.2788161	total: 64.5ms	remaining: 110ms
# 37:	learn: 0.2769767	total: 66ms	remaining: 108ms
# 38:	learn: 0.2735869	total: 67.4ms	remaining: 105ms
# 39:	learn: 0.2707162	total: 69ms	remaining: 103ms
# 40:	learn: 0.2691509	total: 70.4ms	remaining: 101ms
# 41:	learn: 0.2659894	total: 71.9ms	remaining: 99.3ms
# 42:	learn: 0.2641835	total: 73.3ms	remaining: 97.2ms
# 43:	learn: 0.2626416	total: 74.8ms	remaining: 95.2ms
# 44:	learn: 0.2592382	total: 76.6ms	remaining: 93.6ms
# 45:	learn: 0.2572871	total: 78.1ms	remaining: 91.7ms
# 46:	learn: 0.2548035	total: 79.5ms	remaining: 89.7ms
# 47:	learn: 0.2527705	total: 81ms	remaining: 87.7ms
# 48:	learn: 0.2503440	total: 82.6ms	remaining: 86ms
# 49:	learn: 0.2483043	total: 84.2ms	remaining: 84.2ms
# 50:	learn: 0.2449619	total: 85.7ms	remaining: 82.4ms
# 51:	learn: 0.2427578	total: 87.2ms	remaining: 80.5ms
# 52:	learn: 0.2398396	total: 89ms	remaining: 78.9ms
# 53:	learn: 0.2370414	total: 90.7ms	remaining: 77.3ms
# 54:	learn: 0.2349852	total: 92.1ms	remaining: 75.4ms
# 55:	learn: 0.2323466	total: 93.6ms	remaining: 73.5ms
# 56:	learn: 0.2308155	total: 95.2ms	remaining: 71.8ms
# 57:	learn: 0.2288213	total: 96.7ms	remaining: 70ms
# 58:	learn: 0.2266954	total: 98.4ms	remaining: 68.4ms
# 59:	learn: 0.2249378	total: 100ms	remaining: 66.7ms
# 60:	learn: 0.2232148	total: 102ms	remaining: 64.9ms
# 61:	learn: 0.2208978	total: 103ms	remaining: 63.2ms
# 62:	learn: 0.2191280	total: 104ms	remaining: 61.3ms
# 63:	learn: 0.2176463	total: 106ms	remaining: 59.8ms
# 64:	learn: 0.2157646	total: 108ms	remaining: 58.1ms
# 65:	learn: 0.2133737	total: 109ms	remaining: 56.4ms
# 66:	learn: 0.2109692	total: 111ms	remaining: 54.6ms
# 67:	learn: 0.2090138	total: 112ms	remaining: 52.9ms
# 68:	learn: 0.2067143	total: 114ms	remaining: 51.2ms
# 69:	learn: 0.2048326	total: 115ms	remaining: 49.4ms
# 70:	learn: 0.2024858	total: 117ms	remaining: 47.7ms
# 71:	learn: 0.2008270	total: 118ms	remaining: 46ms
# 72:	learn: 0.1992656	total: 120ms	remaining: 44.3ms
# 73:	learn: 0.1980232	total: 121ms	remaining: 42.6ms
# 74:	learn: 0.1964032	total: 123ms	remaining: 40.9ms
# 75:	learn: 0.1949316	total: 124ms	remaining: 39.2ms
# 76:	learn: 0.1929832	total: 126ms	remaining: 37.5ms
# 77:	learn: 0.1913061	total: 127ms	remaining: 35.9ms
# 78:	learn: 0.1897458	total: 129ms	remaining: 34.2ms
# 79:	learn: 0.1881070	total: 130ms	remaining: 32.6ms
# 80:	learn: 0.1868411	total: 132ms	remaining: 30.9ms
# 81:	learn: 0.1845295	total: 133ms	remaining: 29.3ms
# 82:	learn: 0.1831304	total: 135ms	remaining: 27.6ms
# 83:	learn: 0.1818381	total: 136ms	remaining: 25.9ms
# 84:	learn: 0.1806776	total: 138ms	remaining: 24.3ms
# 85:	learn: 0.1794294	total: 139ms	remaining: 22.6ms
# 86:	learn: 0.1777937	total: 141ms	remaining: 21ms
# 87:	learn: 0.1766725	total: 142ms	remaining: 19.4ms
# 88:	learn: 0.1758093	total: 144ms	remaining: 17.8ms
# 89:	learn: 0.1744289	total: 145ms	remaining: 16.1ms
# 90:	learn: 0.1732787	total: 147ms	remaining: 14.6ms
# 91:	learn: 0.1714980	total: 149ms	remaining: 13ms
# 92:	learn: 0.1699263	total: 151ms	remaining: 11.3ms
# 93:	learn: 0.1689336	total: 152ms	remaining: 9.71ms
# 94:	learn: 0.1679253	total: 154ms	remaining: 8.09ms
# 95:	learn: 0.1661436	total: 155ms	remaining: 6.47ms
# 96:	learn: 0.1647451	total: 157ms	remaining: 4.85ms
# 97:	learn: 0.1637426	total: 158ms	remaining: 3.23ms
# 98:	learn: 0.1630222	total: 160ms	remaining: 1.61ms
# 99:	learn: 0.1617026	total: 161ms	remaining: 0us
# 0:	learn: 0.5791299	total: 1.81ms	remaining: 360ms
# 1:	learn: 0.5207276	total: 3.87ms	remaining: 383ms
# 2:	learn: 0.4713883	total: 5.77ms	remaining: 379ms
# 3:	learn: 0.4336783	total: 8.22ms	remaining: 403ms
# 4:	learn: 0.4131625	total: 11ms	remaining: 427ms
# 5:	learn: 0.4030921	total: 13ms	remaining: 419ms
# 6:	learn: 0.3896614	total: 16.2ms	remaining: 448ms
# 7:	learn: 0.3822292	total: 18ms	remaining: 432ms
# 8:	learn: 0.3756249	total: 19.6ms	remaining: 416ms
# 9:	learn: 0.3694965	total: 21.5ms	remaining: 408ms
# 10:	learn: 0.3638205	total: 23ms	remaining: 396ms
# 11:	learn: 0.3585078	total: 25.1ms	remaining: 393ms
# 12:	learn: 0.3524340	total: 27.2ms	remaining: 391ms
# 13:	learn: 0.3493282	total: 28.7ms	remaining: 381ms
# 14:	learn: 0.3469076	total: 31.1ms	remaining: 384ms
# 15:	learn: 0.3410394	total: 33ms	remaining: 380ms
# 16:	learn: 0.3369658	total: 34.8ms	remaining: 374ms
# 17:	learn: 0.3317469	total: 36.1ms	remaining: 365ms
# 18:	learn: 0.3303570	total: 37.8ms	remaining: 360ms
# 19:	learn: 0.3270364	total: 39.3ms	remaining: 354ms
# 20:	learn: 0.3233562	total: 41ms	remaining: 349ms
# 21:	learn: 0.3199409	total: 42.8ms	remaining: 347ms
# 22:	learn: 0.3176706	total: 44.4ms	remaining: 342ms
# 23:	learn: 0.3157491	total: 46ms	remaining: 337ms
# 24:	learn: 0.3134361	total: 47.8ms	remaining: 335ms
# 25:	learn: 0.3098592	total: 49.5ms	remaining: 331ms
# 26:	learn: 0.3094539	total: 50.3ms	remaining: 322ms
# 27:	learn: 0.3060431	total: 51.9ms	remaining: 319ms
# 28:	learn: 0.3045785	total: 53.6ms	remaining: 316ms
# 29:	learn: 0.3033306	total: 55.5ms	remaining: 315ms
# 30:	learn: 0.3000724	total: 57ms	remaining: 311ms
# 31:	learn: 0.2979426	total: 58.5ms	remaining: 307ms
# 32:	learn: 0.2946250	total: 60ms	remaining: 303ms
# 33:	learn: 0.2932233	total: 61.3ms	remaining: 300ms
# 34:	learn: 0.2914317	total: 63ms	remaining: 297ms
# 35:	learn: 0.2890626	total: 64.6ms	remaining: 294ms
# 36:	learn: 0.2863879	total: 66.1ms	remaining: 291ms
# 37:	learn: 0.2835300	total: 67.9ms	remaining: 290ms
# 38:	learn: 0.2812168	total: 70ms	remaining: 289ms
# 39:	learn: 0.2787677	total: 71.5ms	remaining: 286ms
# 40:	learn: 0.2762505	total: 73ms	remaining: 283ms
# 41:	learn: 0.2736888	total: 74.5ms	remaining: 280ms
# 42:	learn: 0.2710822	total: 76.2ms	remaining: 278ms
# 43:	learn: 0.2692111	total: 77.9ms	remaining: 276ms
# 44:	learn: 0.2675139	total: 79.3ms	remaining: 273ms
# 45:	learn: 0.2649031	total: 80.8ms	remaining: 271ms
# 46:	learn: 0.2626140	total: 82.3ms	remaining: 268ms
# 47:	learn: 0.2602760	total: 83.9ms	remaining: 266ms
# 48:	learn: 0.2576763	total: 85.5ms	remaining: 263ms
# 49:	learn: 0.2552430	total: 87ms	remaining: 261ms
# 50:	learn: 0.2534827	total: 88.5ms	remaining: 259ms
# 51:	learn: 0.2504436	total: 90ms	remaining: 256ms
# 52:	learn: 0.2477247	total: 91.6ms	remaining: 254ms
# 53:	learn: 0.2450200	total: 93.3ms	remaining: 252ms
# 54:	learn: 0.2430919	total: 94.8ms	remaining: 250ms
# 55:	learn: 0.2413671	total: 96.3ms	remaining: 248ms
# 56:	learn: 0.2390847	total: 97.8ms	remaining: 245ms
# 57:	learn: 0.2357393	total: 99.5ms	remaining: 244ms
# 58:	learn: 0.2336434	total: 101ms	remaining: 242ms
# 59:	learn: 0.2306002	total: 103ms	remaining: 240ms
# 60:	learn: 0.2292586	total: 105ms	remaining: 238ms
# 61:	learn: 0.2280247	total: 106ms	remaining: 236ms
# 62:	learn: 0.2267604	total: 108ms	remaining: 234ms
# 63:	learn: 0.2242237	total: 109ms	remaining: 232ms
# 64:	learn: 0.2225064	total: 111ms	remaining: 230ms
# 65:	learn: 0.2212310	total: 112ms	remaining: 228ms
# 66:	learn: 0.2188334	total: 114ms	remaining: 226ms
# 67:	learn: 0.2174631	total: 115ms	remaining: 224ms
# 68:	learn: 0.2154755	total: 117ms	remaining: 222ms
# 69:	learn: 0.2134218	total: 119ms	remaining: 220ms
# 70:	learn: 0.2117633	total: 120ms	remaining: 218ms
# 71:	learn: 0.2090885	total: 122ms	remaining: 216ms
# 72:	learn: 0.2070060	total: 123ms	remaining: 214ms
# 73:	learn: 0.2058861	total: 125ms	remaining: 212ms
# 74:	learn: 0.2038223	total: 126ms	remaining: 211ms
# 75:	learn: 0.2015524	total: 129ms	remaining: 210ms
# 76:	learn: 0.2004019	total: 130ms	remaining: 208ms
# 77:	learn: 0.1986275	total: 132ms	remaining: 207ms
# 78:	learn: 0.1969200	total: 134ms	remaining: 205ms
# 79:	learn: 0.1954314	total: 136ms	remaining: 204ms
# 80:	learn: 0.1937825	total: 137ms	remaining: 202ms
# 81:	learn: 0.1929193	total: 139ms	remaining: 200ms
# 82:	learn: 0.1915122	total: 140ms	remaining: 198ms
# 83:	learn: 0.1901201	total: 142ms	remaining: 196ms
# 84:	learn: 0.1879107	total: 144ms	remaining: 194ms
# 85:	learn: 0.1855753	total: 145ms	remaining: 192ms
# 86:	learn: 0.1838457	total: 147ms	remaining: 190ms
# 87:	learn: 0.1818765	total: 148ms	remaining: 189ms
# 88:	learn: 0.1813884	total: 150ms	remaining: 187ms
# 89:	learn: 0.1795039	total: 152ms	remaining: 185ms
# 90:	learn: 0.1781665	total: 153ms	remaining: 183ms
# 91:	learn: 0.1766651	total: 155ms	remaining: 182ms
# 92:	learn: 0.1757410	total: 156ms	remaining: 180ms
# 93:	learn: 0.1745054	total: 158ms	remaining: 178ms
# 94:	learn: 0.1734108	total: 159ms	remaining: 176ms
# 95:	learn: 0.1723534	total: 161ms	remaining: 174ms
# 96:	learn: 0.1719684	total: 162ms	remaining: 172ms
# 97:	learn: 0.1704519	total: 164ms	remaining: 170ms
# 98:	learn: 0.1689909	total: 165ms	remaining: 169ms
# 99:	learn: 0.1674532	total: 167ms	remaining: 167ms
# 100:	learn: 0.1667835	total: 169ms	remaining: 165ms
# 101:	learn: 0.1652998	total: 170ms	remaining: 164ms
# 102:	learn: 0.1642500	total: 172ms	remaining: 162ms
# 103:	learn: 0.1632613	total: 173ms	remaining: 160ms
# 104:	learn: 0.1623930	total: 175ms	remaining: 158ms
# 105:	learn: 0.1613792	total: 176ms	remaining: 156ms
# 106:	learn: 0.1606426	total: 178ms	remaining: 155ms
# 107:	learn: 0.1597772	total: 180ms	remaining: 153ms
# 108:	learn: 0.1583966	total: 181ms	remaining: 151ms
# 109:	learn: 0.1572496	total: 183ms	remaining: 150ms
# 110:	learn: 0.1559036	total: 185ms	remaining: 148ms
# 111:	learn: 0.1547966	total: 188ms	remaining: 147ms
# 112:	learn: 0.1537014	total: 190ms	remaining: 146ms
# 113:	learn: 0.1529039	total: 192ms	remaining: 145ms
# 114:	learn: 0.1519122	total: 194ms	remaining: 144ms
# 115:	learn: 0.1508054	total: 196ms	remaining: 142ms
# 116:	learn: 0.1495245	total: 199ms	remaining: 141ms
# 117:	learn: 0.1487514	total: 201ms	remaining: 140ms
# 118:	learn: 0.1474187	total: 203ms	remaining: 138ms
# 119:	learn: 0.1458665	total: 205ms	remaining: 137ms
# 120:	learn: 0.1450096	total: 207ms	remaining: 135ms
# 121:	learn: 0.1439919	total: 210ms	remaining: 134ms
# 122:	learn: 0.1427095	total: 211ms	remaining: 132ms
# 123:	learn: 0.1418878	total: 213ms	remaining: 131ms
# 124:	learn: 0.1415615	total: 215ms	remaining: 129ms
# 125:	learn: 0.1409201	total: 218ms	remaining: 128ms
# 126:	learn: 0.1398892	total: 220ms	remaining: 126ms
# 127:	learn: 0.1388292	total: 222ms	remaining: 125ms
# 128:	learn: 0.1377712	total: 225ms	remaining: 124ms
# 129:	learn: 0.1369376	total: 226ms	remaining: 122ms
# 130:	learn: 0.1360600	total: 228ms	remaining: 120ms
# 131:	learn: 0.1345337	total: 230ms	remaining: 118ms
# 132:	learn: 0.1334318	total: 232ms	remaining: 117ms
# 133:	learn: 0.1327720	total: 234ms	remaining: 115ms
# 134:	learn: 0.1322169	total: 236ms	remaining: 114ms
# 135:	learn: 0.1311665	total: 238ms	remaining: 112ms
# 136:	learn: 0.1303111	total: 240ms	remaining: 110ms
# 137:	learn: 0.1292400	total: 241ms	remaining: 108ms
# 138:	learn: 0.1281715	total: 243ms	remaining: 107ms
# 139:	learn: 0.1275160	total: 244ms	remaining: 105ms
# 140:	learn: 0.1265579	total: 246ms	remaining: 103ms
# 141:	learn: 0.1255203	total: 248ms	remaining: 101ms
# 142:	learn: 0.1249172	total: 249ms	remaining: 99.4ms
# 143:	learn: 0.1244345	total: 251ms	remaining: 97.5ms
# 144:	learn: 0.1236717	total: 252ms	remaining: 95.7ms
# 145:	learn: 0.1230308	total: 254ms	remaining: 94ms
# 146:	learn: 0.1221234	total: 256ms	remaining: 92.2ms
# 147:	learn: 0.1210525	total: 258ms	remaining: 90.7ms
# 148:	learn: 0.1201631	total: 260ms	remaining: 88.8ms
# 149:	learn: 0.1190650	total: 261ms	remaining: 87.1ms
# 150:	learn: 0.1181499	total: 263ms	remaining: 85.3ms
# 151:	learn: 0.1176392	total: 264ms	remaining: 83.5ms
# 152:	learn: 0.1169614	total: 266ms	remaining: 81.7ms
# 153:	learn: 0.1164264	total: 268ms	remaining: 80.1ms
# 154:	learn: 0.1156976	total: 270ms	remaining: 78.3ms
# 155:	learn: 0.1149331	total: 271ms	remaining: 76.4ms
# 156:	learn: 0.1141738	total: 272ms	remaining: 74.6ms
# 157:	learn: 0.1133895	total: 274ms	remaining: 72.8ms
# 158:	learn: 0.1129973	total: 276ms	remaining: 71.1ms
# 159:	learn: 0.1122586	total: 277ms	remaining: 69.3ms
# 160:	learn: 0.1112679	total: 279ms	remaining: 67.5ms
# 161:	learn: 0.1104415	total: 280ms	remaining: 65.7ms
# 162:	learn: 0.1095809	total: 282ms	remaining: 63.9ms
# 163:	learn: 0.1091067	total: 283ms	remaining: 62.2ms
# 164:	learn: 0.1083132	total: 285ms	remaining: 60.4ms
# 165:	learn: 0.1077972	total: 287ms	remaining: 58.7ms
# 166:	learn: 0.1073103	total: 288ms	remaining: 57ms
# 167:	learn: 0.1065195	total: 290ms	remaining: 55.3ms
# 168:	learn: 0.1056966	total: 292ms	remaining: 53.6ms
# 169:	learn: 0.1051690	total: 294ms	remaining: 51.9ms
# 170:	learn: 0.1046826	total: 295ms	remaining: 50.1ms
# 171:	learn: 0.1035079	total: 297ms	remaining: 48.4ms
# 172:	learn: 0.1030188	total: 299ms	remaining: 46.6ms
# 173:	learn: 0.1026245	total: 300ms	remaining: 44.9ms
# 174:	learn: 0.1017712	total: 302ms	remaining: 43.1ms
# 175:	learn: 0.1013734	total: 303ms	remaining: 41.4ms
# 176:	learn: 0.1007061	total: 305ms	remaining: 39.6ms
# 177:	learn: 0.1001949	total: 307ms	remaining: 37.9ms
# 178:	learn: 0.0998233	total: 308ms	remaining: 36.1ms
# 179:	learn: 0.0991190	total: 310ms	remaining: 34.4ms
# 180:	learn: 0.0984988	total: 312ms	remaining: 32.7ms
# 181:	learn: 0.0979411	total: 313ms	remaining: 31ms
# 182:	learn: 0.0974686	total: 315ms	remaining: 29.2ms
# 183:	learn: 0.0967330	total: 316ms	remaining: 27.5ms
# 184:	learn: 0.0961761	total: 318ms	remaining: 25.7ms
# 185:	learn: 0.0956591	total: 319ms	remaining: 24ms
# 186:	learn: 0.0948319	total: 321ms	remaining: 22.3ms
# 187:	learn: 0.0943205	total: 322ms	remaining: 20.6ms
# 188:	learn: 0.0937786	total: 324ms	remaining: 18.8ms
# 189:	learn: 0.0933815	total: 325ms	remaining: 17.1ms
# 190:	learn: 0.0928481	total: 327ms	remaining: 15.4ms
# 191:	learn: 0.0925477	total: 329ms	remaining: 13.7ms
# 192:	learn: 0.0921947	total: 330ms	remaining: 12ms
# 193:	learn: 0.0919156	total: 332ms	remaining: 10.3ms
# 194:	learn: 0.0914581	total: 333ms	remaining: 8.55ms
# 195:	learn: 0.0909557	total: 335ms	remaining: 6.84ms
# 196:	learn: 0.0901708	total: 336ms	remaining: 5.12ms
# 197:	learn: 0.0899294	total: 338ms	remaining: 3.41ms
# 198:	learn: 0.0894405	total: 340ms	remaining: 1.71ms
# 199:	learn: 0.0885543	total: 341ms	remaining: 0us
# 0:	learn: 0.5795204	total: 1.42ms	remaining: 283ms
# 1:	learn: 0.5215347	total: 2.88ms	remaining: 285ms
# 2:	learn: 0.4735810	total: 4.24ms	remaining: 278ms
# 3:	learn: 0.4407544	total: 5.7ms	remaining: 279ms
# 4:	learn: 0.4189615	total: 7.27ms	remaining: 284ms
# 5:	learn: 0.4055978	total: 9.41ms	remaining: 304ms
# 6:	learn: 0.3878921	total: 11.3ms	remaining: 313ms
# 7:	learn: 0.3802208	total: 13.7ms	remaining: 329ms
# 8:	learn: 0.3742410	total: 15.7ms	remaining: 334ms
# 9:	learn: 0.3687338	total: 18.3ms	remaining: 347ms
# 10:	learn: 0.3648120	total: 20.6ms	remaining: 354ms
# 11:	learn: 0.3575011	total: 22.9ms	remaining: 359ms
# 12:	learn: 0.3538237	total: 25.2ms	remaining: 362ms
# 13:	learn: 0.3486212	total: 27.5ms	remaining: 366ms
# 14:	learn: 0.3456390	total: 30.2ms	remaining: 372ms
# 15:	learn: 0.3417505	total: 32.2ms	remaining: 371ms
# 16:	learn: 0.3390662	total: 34.6ms	remaining: 372ms
# 17:	learn: 0.3352784	total: 37.9ms	remaining: 383ms
# 18:	learn: 0.3299918	total: 39.5ms	remaining: 377ms
# 19:	learn: 0.3261824	total: 41ms	remaining: 369ms
# 20:	learn: 0.3229361	total: 42.7ms	remaining: 364ms
# 21:	learn: 0.3179023	total: 44.9ms	remaining: 363ms
# 22:	learn: 0.3146870	total: 46.4ms	remaining: 357ms
# 23:	learn: 0.3121669	total: 48.1ms	remaining: 353ms
# 24:	learn: 0.3098501	total: 49.9ms	remaining: 349ms
# 25:	learn: 0.3072211	total: 52.5ms	remaining: 351ms
# 26:	learn: 0.3068173	total: 53.8ms	remaining: 345ms
# 27:	learn: 0.3036407	total: 56.7ms	remaining: 348ms
# 28:	learn: 0.3015470	total: 59.4ms	remaining: 350ms
# 29:	learn: 0.2982686	total: 61.5ms	remaining: 348ms
# 30:	learn: 0.2953592	total: 63.6ms	remaining: 347ms
# 31:	learn: 0.2941025	total: 67.4ms	remaining: 354ms
# 32:	learn: 0.2906500	total: 69.6ms	remaining: 352ms
# 33:	learn: 0.2877310	total: 74ms	remaining: 361ms
# 34:	learn: 0.2848586	total: 75.9ms	remaining: 358ms
# 35:	learn: 0.2824673	total: 77.7ms	remaining: 354ms
# 36:	learn: 0.2808686	total: 80.1ms	remaining: 353ms
# 37:	learn: 0.2768446	total: 82.6ms	remaining: 352ms
# 38:	learn: 0.2733409	total: 84.5ms	remaining: 349ms
# 39:	learn: 0.2709249	total: 87.7ms	remaining: 351ms
# 40:	learn: 0.2683762	total: 95.9ms	remaining: 372ms
# 41:	learn: 0.2656898	total: 99ms	remaining: 372ms
# 42:	learn: 0.2639689	total: 102ms	remaining: 374ms
# 43:	learn: 0.2627694	total: 106ms	remaining: 377ms
# 44:	learn: 0.2595168	total: 108ms	remaining: 373ms
# 45:	learn: 0.2567206	total: 111ms	remaining: 370ms
# 46:	learn: 0.2540903	total: 112ms	remaining: 366ms
# 47:	learn: 0.2516052	total: 115ms	remaining: 364ms
# 48:	learn: 0.2495976	total: 118ms	remaining: 364ms
# 49:	learn: 0.2471275	total: 126ms	remaining: 377ms
# 50:	learn: 0.2448467	total: 128ms	remaining: 375ms
# 51:	learn: 0.2429868	total: 131ms	remaining: 373ms
# 52:	learn: 0.2404678	total: 139ms	remaining: 387ms
# 53:	learn: 0.2389518	total: 143ms	remaining: 386ms
# 54:	learn: 0.2369897	total: 146ms	remaining: 385ms
# 55:	learn: 0.2343849	total: 152ms	remaining: 391ms
# 56:	learn: 0.2325000	total: 155ms	remaining: 390ms
# 57:	learn: 0.2307144	total: 158ms	remaining: 386ms
# 58:	learn: 0.2282102	total: 164ms	remaining: 392ms
# 59:	learn: 0.2262131	total: 168ms	remaining: 392ms
# 60:	learn: 0.2232095	total: 181ms	remaining: 412ms
# 61:	learn: 0.2207500	total: 184ms	remaining: 410ms
# 62:	learn: 0.2188537	total: 190ms	remaining: 414ms
# 63:	learn: 0.2171087	total: 194ms	remaining: 412ms
# 64:	learn: 0.2157065	total: 198ms	remaining: 412ms
# 65:	learn: 0.2135847	total: 206ms	remaining: 417ms
# 66:	learn: 0.2111268	total: 209ms	remaining: 414ms
# 67:	learn: 0.2094566	total: 212ms	remaining: 411ms
# 68:	learn: 0.2073387	total: 215ms	remaining: 408ms
# 69:	learn: 0.2062157	total: 218ms	remaining: 405ms
# 70:	learn: 0.2053879	total: 221ms	remaining: 401ms
# 71:	learn: 0.2032035	total: 223ms	remaining: 396ms
# 72:	learn: 0.2013815	total: 226ms	remaining: 393ms
# 73:	learn: 0.1996747	total: 230ms	remaining: 391ms
# 74:	learn: 0.1988314	total: 235ms	remaining: 392ms
# 75:	learn: 0.1965686	total: 238ms	remaining: 389ms
# 76:	learn: 0.1948784	total: 240ms	remaining: 384ms
# 77:	learn: 0.1934536	total: 244ms	remaining: 382ms
# 78:	learn: 0.1922882	total: 247ms	remaining: 379ms
# 79:	learn: 0.1912434	total: 251ms	remaining: 377ms
# 80:	learn: 0.1896919	total: 255ms	remaining: 374ms
# 81:	learn: 0.1883057	total: 260ms	remaining: 374ms
# 82:	learn: 0.1870083	total: 265ms	remaining: 374ms
# 83:	learn: 0.1851453	total: 268ms	remaining: 370ms
# 84:	learn: 0.1831772	total: 270ms	remaining: 366ms
# 85:	learn: 0.1822320	total: 273ms	remaining: 361ms
# 86:	learn: 0.1818789	total: 276ms	remaining: 358ms
# 87:	learn: 0.1804668	total: 278ms	remaining: 354ms
# 88:	learn: 0.1793659	total: 281ms	remaining: 350ms
# 89:	learn: 0.1770726	total: 283ms	remaining: 346ms
# 90:	learn: 0.1759298	total: 285ms	remaining: 341ms
# 91:	learn: 0.1747886	total: 289ms	remaining: 339ms
# 92:	learn: 0.1739441	total: 294ms	remaining: 338ms
# 93:	learn: 0.1724948	total: 298ms	remaining: 336ms
# 94:	learn: 0.1710584	total: 300ms	remaining: 331ms
# 95:	learn: 0.1701182	total: 303ms	remaining: 328ms
# 96:	learn: 0.1683425	total: 306ms	remaining: 325ms
# 97:	learn: 0.1671591	total: 309ms	remaining: 321ms
# 98:	learn: 0.1661071	total: 311ms	remaining: 317ms
# 99:	learn: 0.1648973	total: 313ms	remaining: 313ms
# 100:	learn: 0.1636179	total: 315ms	remaining: 309ms
# 101:	learn: 0.1625331	total: 321ms	remaining: 309ms
# 102:	learn: 0.1613366	total: 327ms	remaining: 308ms
# 103:	learn: 0.1605727	total: 331ms	remaining: 306ms
# 104:	learn: 0.1596892	total: 333ms	remaining: 301ms
# 105:	learn: 0.1587106	total: 336ms	remaining: 298ms
# 106:	learn: 0.1581534	total: 338ms	remaining: 294ms
# 107:	learn: 0.1571556	total: 341ms	remaining: 290ms
# 108:	learn: 0.1560842	total: 343ms	remaining: 286ms
# 109:	learn: 0.1552994	total: 345ms	remaining: 282ms
# 110:	learn: 0.1541314	total: 347ms	remaining: 278ms
# 111:	learn: 0.1531870	total: 356ms	remaining: 279ms
# 112:	learn: 0.1522855	total: 359ms	remaining: 277ms
# 113:	learn: 0.1505321	total: 362ms	remaining: 273ms
# 114:	learn: 0.1495869	total: 369ms	remaining: 273ms
# 115:	learn: 0.1487361	total: 375ms	remaining: 272ms
# 116:	learn: 0.1478307	total: 377ms	remaining: 268ms
# 117:	learn: 0.1467778	total: 385ms	remaining: 267ms
# 118:	learn: 0.1457296	total: 389ms	remaining: 264ms
# 119:	learn: 0.1445905	total: 391ms	remaining: 261ms
# 120:	learn: 0.1437378	total: 393ms	remaining: 257ms
# 121:	learn: 0.1430214	total: 399ms	remaining: 255ms
# 122:	learn: 0.1424251	total: 405ms	remaining: 253ms
# 123:	learn: 0.1415970	total: 407ms	remaining: 249ms
# 124:	learn: 0.1406723	total: 413ms	remaining: 248ms
# 125:	learn: 0.1402257	total: 421ms	remaining: 247ms
# 126:	learn: 0.1389210	total: 423ms	remaining: 243ms
# 127:	learn: 0.1382096	total: 431ms	remaining: 242ms
# 128:	learn: 0.1368003	total: 434ms	remaining: 239ms
# 129:	learn: 0.1353822	total: 437ms	remaining: 235ms
# 130:	learn: 0.1347059	total: 439ms	remaining: 231ms
# 131:	learn: 0.1344608	total: 441ms	remaining: 227ms
# 132:	learn: 0.1336345	total: 444ms	remaining: 224ms
# 133:	learn: 0.1331525	total: 447ms	remaining: 220ms
# 134:	learn: 0.1319584	total: 450ms	remaining: 216ms
# 135:	learn: 0.1313113	total: 452ms	remaining: 213ms
# 136:	learn: 0.1301871	total: 458ms	remaining: 211ms
# 137:	learn: 0.1296448	total: 464ms	remaining: 208ms
# 138:	learn: 0.1290880	total: 467ms	remaining: 205ms
# 139:	learn: 0.1281495	total: 469ms	remaining: 201ms
# 140:	learn: 0.1273234	total: 474ms	remaining: 199ms
# 141:	learn: 0.1265764	total: 478ms	remaining: 195ms
# 142:	learn: 0.1261584	total: 480ms	remaining: 191ms
# 143:	learn: 0.1254920	total: 482ms	remaining: 188ms
# 144:	learn: 0.1247539	total: 490ms	remaining: 186ms
# 145:	learn: 0.1240229	total: 494ms	remaining: 183ms
# 146:	learn: 0.1228473	total: 497ms	remaining: 179ms
# 147:	learn: 0.1216982	total: 502ms	remaining: 176ms
# 148:	learn: 0.1209291	total: 504ms	remaining: 173ms
# 149:	learn: 0.1199773	total: 510ms	remaining: 170ms
# 150:	learn: 0.1189881	total: 515ms	remaining: 167ms
# 151:	learn: 0.1183511	total: 518ms	remaining: 163ms
# 152:	learn: 0.1178173	total: 522ms	remaining: 160ms
# 153:	learn: 0.1173451	total: 525ms	remaining: 157ms
# 154:	learn: 0.1167005	total: 528ms	remaining: 153ms
# 155:	learn: 0.1160227	total: 531ms	remaining: 150ms
# 156:	learn: 0.1153021	total: 534ms	remaining: 146ms
# 157:	learn: 0.1140128	total: 536ms	remaining: 143ms
# 158:	learn: 0.1134992	total: 538ms	remaining: 139ms
# 159:	learn: 0.1126819	total: 541ms	remaining: 135ms
# 160:	learn: 0.1118815	total: 544ms	remaining: 132ms
# 161:	learn: 0.1112826	total: 549ms	remaining: 129ms
# 162:	learn: 0.1105720	total: 554ms	remaining: 126ms
# 163:	learn: 0.1102532	total: 558ms	remaining: 123ms
# 164:	learn: 0.1097414	total: 563ms	remaining: 119ms
# 165:	learn: 0.1087592	total: 567ms	remaining: 116ms
# 166:	learn: 0.1081856	total: 570ms	remaining: 113ms
# 167:	learn: 0.1076782	total: 573ms	remaining: 109ms
# 168:	learn: 0.1071866	total: 576ms	remaining: 106ms
# 169:	learn: 0.1062024	total: 578ms	remaining: 102ms
# 170:	learn: 0.1055026	total: 580ms	remaining: 98.4ms
# 171:	learn: 0.1050733	total: 583ms	remaining: 94.8ms
# 172:	learn: 0.1045450	total: 585ms	remaining: 91.2ms
# 173:	learn: 0.1038429	total: 587ms	remaining: 87.7ms
# 174:	learn: 0.1029358	total: 590ms	remaining: 84.3ms
# 175:	learn: 0.1023744	total: 593ms	remaining: 80.9ms
# 176:	learn: 0.1020257	total: 597ms	remaining: 77.5ms
# 177:	learn: 0.1014077	total: 599ms	remaining: 74ms
# 178:	learn: 0.1007943	total: 602ms	remaining: 70.6ms
# 179:	learn: 0.1000058	total: 608ms	remaining: 67.6ms
# 180:	learn: 0.0996005	total: 611ms	remaining: 64.1ms
# 181:	learn: 0.0984802	total: 616ms	remaining: 60.9ms
# 182:	learn: 0.0977284	total: 621ms	remaining: 57.7ms
# 183:	learn: 0.0970193	total: 625ms	remaining: 54.4ms
# 184:	learn: 0.0964310	total: 633ms	remaining: 51.3ms
# 185:	learn: 0.0959431	total: 636ms	remaining: 47.9ms
# 186:	learn: 0.0954444	total: 640ms	remaining: 44.5ms
# 187:	learn: 0.0950375	total: 642ms	remaining: 41ms
# 188:	learn: 0.0945026	total: 649ms	remaining: 37.8ms
# 189:	learn: 0.0936933	total: 653ms	remaining: 34.4ms
# 190:	learn: 0.0932729	total: 656ms	remaining: 30.9ms
# 191:	learn: 0.0929453	total: 658ms	remaining: 27.4ms
# 192:	learn: 0.0922518	total: 661ms	remaining: 24ms
# 193:	learn: 0.0916661	total: 664ms	remaining: 20.5ms
# 194:	learn: 0.0910212	total: 667ms	remaining: 17.1ms
# 195:	learn: 0.0903902	total: 669ms	remaining: 13.7ms
# 196:	learn: 0.0899346	total: 671ms	remaining: 10.2ms
# 197:	learn: 0.0893691	total: 674ms	remaining: 6.81ms
# 198:	learn: 0.0889441	total: 677ms	remaining: 3.4ms
# 199:	learn: 0.0882048	total: 681ms	remaining: 0us
# 0:	learn: 0.5805381	total: 2.21ms	remaining: 441ms
# 1:	learn: 0.5243898	total: 9.16ms	remaining: 907ms
# 2:	learn: 0.4702008	total: 13.3ms	remaining: 875ms
# 3:	learn: 0.4456770	total: 17.1ms	remaining: 840ms
# 4:	learn: 0.4248024	total: 23.5ms	remaining: 915ms
# 5:	learn: 0.4129254	total: 27.2ms	remaining: 880ms
# 6:	learn: 0.4001928	total: 29.3ms	remaining: 807ms
# 7:	learn: 0.3920261	total: 31.2ms	remaining: 748ms
# 8:	learn: 0.3821001	total: 33.5ms	remaining: 711ms
# 9:	learn: 0.3754033	total: 38.5ms	remaining: 731ms
# 10:	learn: 0.3722210	total: 44.5ms	remaining: 765ms
# 11:	learn: 0.3651385	total: 46.6ms	remaining: 730ms
# 12:	learn: 0.3595822	total: 56.1ms	remaining: 806ms
# 13:	learn: 0.3565160	total: 59.2ms	remaining: 786ms
# 14:	learn: 0.3527029	total: 61.7ms	remaining: 761ms
# 15:	learn: 0.3482731	total: 63.8ms	remaining: 734ms
# 16:	learn: 0.3454892	total: 70.3ms	remaining: 757ms
# 17:	learn: 0.3387587	total: 75.3ms	remaining: 762ms
# 18:	learn: 0.3337333	total: 77.5ms	remaining: 738ms
# 19:	learn: 0.3307931	total: 86.2ms	remaining: 776ms
# 20:	learn: 0.3275080	total: 89.4ms	remaining: 762ms
# 21:	learn: 0.3235341	total: 92.2ms	remaining: 746ms
# 22:	learn: 0.3221876	total: 94ms	remaining: 723ms
# 23:	learn: 0.3181937	total: 96.4ms	remaining: 707ms
# 24:	learn: 0.3172805	total: 98.7ms	remaining: 691ms
# 25:	learn: 0.3154383	total: 102ms	remaining: 685ms
# 26:	learn: 0.3151187	total: 104ms	remaining: 663ms
# 27:	learn: 0.3130428	total: 105ms	remaining: 648ms
# ...
# 702:	learn: 0.0193488	total: 1.32s	remaining: 558ms
# 703:	learn: 0.0193039	total: 1.32s	remaining: 556ms
# 704:	learn: 0.0192665	total: 1.32s	remaining: 554ms
# 705:	learn: 0.0192146	total: 1.32s	remaining: 552ms
# 706:	learn: 0.0191923	total: 1.33s	remaining: 550ms
# 707:	learn: 0.0191316	total: 1.33s	remaining: 548ms
# 708:	learn: 0.0190192	total: 1.33s	remaining: 546ms
# 709:	learn: 0.0189586	total: 1.33s	remaining: 545ms
# 710:	learn: 0.0189444	total: 1.33s	remaining: 543ms
# 711:	learn: 0.0189073	total: 1.34s	remaining: 541ms
# 712:	learn: 0.0188734	total: 1.34s	remaining: 539ms
# 713:	learn: 0.0188319	total: 1.34s	remaining: 537ms
# 714:	learn: 0.0187395	total: 1.34s	remaining: 535ms
# 715:	learn: 0.0186877	total: 1.34s	remaining: 533ms
# 716:	learn: 0.0186360	total: 1.34s	remaining: 531ms
# 717:	learn: 0.0185659	total: 1.35s	remaining: 529ms
# 718:	learn: 0.0185198	total: 1.35s	remaining: 527ms
# 719:	learn: 0.0184801	total: 1.35s	remaining: 525ms
# 720:	learn: 0.0184398	total: 1.35s	remaining: 523ms
# 721:	learn: 0.0183964	total: 1.35s	remaining: 521ms
# 722:	learn: 0.0183622	total: 1.35s	remaining: 519ms
# 723:	learn: 0.0183357	total: 1.36s	remaining: 517ms
# 724:	learn: 0.0183228	total: 1.36s	remaining: 515ms
# 725:	learn: 0.0182791	total: 1.36s	remaining: 513ms
# 726:	learn: 0.0182354	total: 1.36s	remaining: 511ms
# 727:	learn: 0.0181912	total: 1.36s	remaining: 509ms
# 728:	learn: 0.0181575	total: 1.36s	remaining: 507ms
# 729:	learn: 0.0181329	total: 1.37s	remaining: 506ms
# 730:	learn: 0.0181100	total: 1.37s	remaining: 504ms
# 731:	learn: 0.0180885	total: 1.37s	remaining: 502ms
# 732:	learn: 0.0180324	total: 1.37s	remaining: 500ms
# 733:	learn: 0.0179912	total: 1.37s	remaining: 498ms
# 734:	learn: 0.0179472	total: 1.37s	remaining: 496ms
# 735:	learn: 0.0179089	total: 1.38s	remaining: 494ms
# 736:	learn: 0.0178571	total: 1.38s	remaining: 492ms
# 737:	learn: 0.0178134	total: 1.38s	remaining: 490ms
# 738:	learn: 0.0177580	total: 1.38s	remaining: 488ms
# 739:	learn: 0.0176927	total: 1.38s	remaining: 486ms
# 740:	learn: 0.0176470	total: 1.38s	remaining: 484ms
# 741:	learn: 0.0175891	total: 1.39s	remaining: 482ms
# 742:	learn: 0.0175456	total: 1.39s	remaining: 480ms
# 743:	learn: 0.0174961	total: 1.39s	remaining: 478ms
# 744:	learn: 0.0174653	total: 1.39s	remaining: 476ms
# 745:	learn: 0.0174567	total: 1.39s	remaining: 474ms
# 746:	learn: 0.0174243	total: 1.4s	remaining: 472ms
# 747:	learn: 0.0173897	total: 1.4s	remaining: 471ms
# 748:	learn: 0.0173627	total: 1.4s	remaining: 469ms
# 749:	learn: 0.0173430	total: 1.4s	remaining: 467ms
# 750:	learn: 0.0172717	total: 1.4s	remaining: 465ms
# 751:	learn: 0.0172514	total: 1.4s	remaining: 463ms
# 752:	learn: 0.0172449	total: 1.4s	remaining: 461ms
# 753:	learn: 0.0171979	total: 1.41s	remaining: 459ms
# 754:	learn: 0.0171884	total: 1.41s	remaining: 457ms
# 755:	learn: 0.0171625	total: 1.41s	remaining: 456ms
# 756:	learn: 0.0171455	total: 1.41s	remaining: 454ms
# 757:	learn: 0.0171134	total: 1.42s	remaining: 452ms
# 758:	learn: 0.0171013	total: 1.42s	remaining: 450ms
# 759:	learn: 0.0170749	total: 1.42s	remaining: 449ms
# 760:	learn: 0.0170376	total: 1.42s	remaining: 447ms
# 761:	learn: 0.0169997	total: 1.42s	remaining: 445ms
# 762:	learn: 0.0169259	total: 1.43s	remaining: 443ms
# 763:	learn: 0.0169016	total: 1.43s	remaining: 441ms
# 764:	learn: 0.0168719	total: 1.43s	remaining: 440ms
# 765:	learn: 0.0168601	total: 1.43s	remaining: 438ms
# 766:	learn: 0.0168384	total: 1.44s	remaining: 436ms
# 767:	learn: 0.0168110	total: 1.44s	remaining: 434ms
# 768:	learn: 0.0168007	total: 1.44s	remaining: 432ms
# 769:	learn: 0.0167651	total: 1.44s	remaining: 431ms
# 770:	learn: 0.0167349	total: 1.44s	remaining: 429ms
# 771:	learn: 0.0167082	total: 1.45s	remaining: 427ms
# 772:	learn: 0.0166343	total: 1.45s	remaining: 426ms
# 773:	learn: 0.0165955	total: 1.45s	remaining: 424ms
# 774:	learn: 0.0165726	total: 1.45s	remaining: 422ms
# 775:	learn: 0.0165215	total: 1.45s	remaining: 420ms
# 776:	learn: 0.0164960	total: 1.46s	remaining: 418ms
# 777:	learn: 0.0164540	total: 1.46s	remaining: 416ms
# 778:	learn: 0.0164226	total: 1.46s	remaining: 414ms
# 779:	learn: 0.0164047	total: 1.46s	remaining: 412ms
# 780:	learn: 0.0163519	total: 1.46s	remaining: 410ms
# 781:	learn: 0.0163215	total: 1.46s	remaining: 408ms
# 782:	learn: 0.0162849	total: 1.47s	remaining: 406ms
# 783:	learn: 0.0162469	total: 1.47s	remaining: 405ms
# 784:	learn: 0.0161775	total: 1.47s	remaining: 403ms
# 785:	learn: 0.0161486	total: 1.47s	remaining: 401ms
# 786:	learn: 0.0161106	total: 1.47s	remaining: 399ms
# 787:	learn: 0.0160877	total: 1.48s	remaining: 397ms
# 788:	learn: 0.0160558	total: 1.48s	remaining: 395ms
# 789:	learn: 0.0160279	total: 1.48s	remaining: 393ms
# 790:	learn: 0.0160047	total: 1.48s	remaining: 391ms
# 791:	learn: 0.0159708	total: 1.48s	remaining: 389ms
# 792:	learn: 0.0159339	total: 1.48s	remaining: 388ms
# 793:	learn: 0.0159181	total: 1.49s	remaining: 386ms
# 794:	learn: 0.0158693	total: 1.49s	remaining: 384ms
# 795:	learn: 0.0158330	total: 1.49s	remaining: 382ms
# 796:	learn: 0.0158009	total: 1.49s	remaining: 380ms
# 797:	learn: 0.0157914	total: 1.49s	remaining: 378ms
# 798:	learn: 0.0157592	total: 1.49s	remaining: 376ms
# 799:	learn: 0.0157273	total: 1.5s	remaining: 374ms
# 800:	learn: 0.0156821	total: 1.5s	remaining: 372ms
# 801:	learn: 0.0156430	total: 1.5s	remaining: 370ms
# 802:	learn: 0.0156211	total: 1.5s	remaining: 368ms
# 803:	learn: 0.0155937	total: 1.5s	remaining: 366ms
# 804:	learn: 0.0155652	total: 1.5s	remaining: 364ms
# 805:	learn: 0.0154967	total: 1.5s	remaining: 362ms
# 806:	learn: 0.0154571	total: 1.51s	remaining: 361ms
# 807:	learn: 0.0154244	total: 1.51s	remaining: 359ms
# 808:	learn: 0.0153975	total: 1.51s	remaining: 357ms
# 809:	learn: 0.0153672	total: 1.51s	remaining: 355ms
# 810:	learn: 0.0153494	total: 1.51s	remaining: 353ms
# 811:	learn: 0.0153377	total: 1.51s	remaining: 351ms
# 812:	learn: 0.0152974	total: 1.52s	remaining: 349ms
# 813:	learn: 0.0152688	total: 1.52s	remaining: 347ms
# 814:	learn: 0.0152289	total: 1.52s	remaining: 345ms
# 815:	learn: 0.0152063	total: 1.52s	remaining: 343ms
# 816:	learn: 0.0151960	total: 1.52s	remaining: 341ms
# 817:	learn: 0.0151622	total: 1.53s	remaining: 340ms
# 818:	learn: 0.0151332	total: 1.53s	remaining: 338ms
# 819:	learn: 0.0151123	total: 1.53s	remaining: 336ms
# 820:	learn: 0.0150653	total: 1.53s	remaining: 334ms
# 821:	learn: 0.0150431	total: 1.53s	remaining: 332ms
# 822:	learn: 0.0150281	total: 1.53s	remaining: 330ms
# 823:	learn: 0.0150078	total: 1.54s	remaining: 328ms
# 824:	learn: 0.0149583	total: 1.54s	remaining: 326ms
# 825:	learn: 0.0149156	total: 1.54s	remaining: 324ms
# 826:	learn: 0.0149001	total: 1.54s	remaining: 322ms
# 827:	learn: 0.0148792	total: 1.54s	remaining: 320ms
# 828:	learn: 0.0148231	total: 1.54s	remaining: 319ms
# 829:	learn: 0.0147817	total: 1.55s	remaining: 317ms
# 830:	learn: 0.0147411	total: 1.55s	remaining: 315ms
# 831:	learn: 0.0147128	total: 1.55s	remaining: 313ms
# 832:	learn: 0.0146883	total: 1.55s	remaining: 311ms
# 833:	learn: 0.0146581	total: 1.55s	remaining: 309ms
# 834:	learn: 0.0146261	total: 1.55s	remaining: 307ms
# 835:	learn: 0.0145876	total: 1.56s	remaining: 305ms
# 836:	learn: 0.0145686	total: 1.56s	remaining: 303ms
# 837:	learn: 0.0145370	total: 1.56s	remaining: 301ms
# 838:	learn: 0.0145047	total: 1.56s	remaining: 300ms
# 839:	learn: 0.0144814	total: 1.56s	remaining: 298ms
# 840:	learn: 0.0144599	total: 1.56s	remaining: 296ms
# 841:	learn: 0.0144067	total: 1.56s	remaining: 294ms
# 842:	learn: 0.0143999	total: 1.57s	remaining: 292ms
# 843:	learn: 0.0143632	total: 1.57s	remaining: 290ms
# 844:	learn: 0.0143377	total: 1.57s	remaining: 288ms
# 845:	learn: 0.0143145	total: 1.57s	remaining: 286ms
# 846:	learn: 0.0142928	total: 1.57s	remaining: 284ms
# 847:	learn: 0.0142823	total: 1.58s	remaining: 283ms
# 848:	learn: 0.0142698	total: 1.58s	remaining: 281ms
# 849:	learn: 0.0142511	total: 1.58s	remaining: 279ms
# 850:	learn: 0.0142081	total: 1.58s	remaining: 277ms
# 851:	learn: 0.0141844	total: 1.58s	remaining: 275ms
# 852:	learn: 0.0141362	total: 1.58s	remaining: 273ms
# 853:	learn: 0.0141179	total: 1.58s	remaining: 271ms
# 854:	learn: 0.0140834	total: 1.59s	remaining: 269ms
# 855:	learn: 0.0140591	total: 1.59s	remaining: 267ms
# 856:	learn: 0.0140403	total: 1.59s	remaining: 266ms
# 857:	learn: 0.0140192	total: 1.59s	remaining: 264ms
# 858:	learn: 0.0139986	total: 1.6s	remaining: 262ms
# 859:	learn: 0.0139524	total: 1.6s	remaining: 260ms
# 860:	learn: 0.0139276	total: 1.6s	remaining: 258ms
# 861:	learn: 0.0139061	total: 1.6s	remaining: 257ms
# 862:	learn: 0.0138904	total: 1.6s	remaining: 255ms
# 863:	learn: 0.0138701	total: 1.61s	remaining: 253ms
# 864:	learn: 0.0138390	total: 1.61s	remaining: 251ms
# 865:	learn: 0.0138148	total: 1.61s	remaining: 249ms
# 866:	learn: 0.0137969	total: 1.61s	remaining: 248ms
# 867:	learn: 0.0137596	total: 1.61s	remaining: 246ms
# 868:	learn: 0.0137406	total: 1.62s	remaining: 244ms
# 869:	learn: 0.0137245	total: 1.62s	remaining: 242ms
# 870:	learn: 0.0137026	total: 1.62s	remaining: 240ms
# 871:	learn: 0.0136860	total: 1.63s	remaining: 239ms
# 872:	learn: 0.0136608	total: 1.63s	remaining: 237ms
# 873:	learn: 0.0136426	total: 1.63s	remaining: 235ms
# 874:	learn: 0.0135963	total: 1.63s	remaining: 233ms
# 875:	learn: 0.0135663	total: 1.63s	remaining: 231ms
# 876:	learn: 0.0135383	total: 1.63s	remaining: 229ms
# 877:	learn: 0.0135152	total: 1.64s	remaining: 227ms
# 878:	learn: 0.0134928	total: 1.64s	remaining: 225ms
# 879:	learn: 0.0134728	total: 1.64s	remaining: 224ms
# 880:	learn: 0.0134406	total: 1.64s	remaining: 222ms
# 881:	learn: 0.0134099	total: 1.64s	remaining: 220ms
# 882:	learn: 0.0133836	total: 1.65s	remaining: 218ms
# 883:	learn: 0.0133663	total: 1.65s	remaining: 216ms
# 884:	learn: 0.0133149	total: 1.65s	remaining: 214ms
# 885:	learn: 0.0132982	total: 1.65s	remaining: 212ms
# 886:	learn: 0.0132642	total: 1.65s	remaining: 211ms
# 887:	learn: 0.0132524	total: 1.65s	remaining: 209ms
# 888:	learn: 0.0132398	total: 1.66s	remaining: 207ms
# 889:	learn: 0.0132230	total: 1.66s	remaining: 205ms
# 890:	learn: 0.0131997	total: 1.66s	remaining: 203ms
# 891:	learn: 0.0131724	total: 1.66s	remaining: 201ms
# 892:	learn: 0.0131411	total: 1.66s	remaining: 199ms
# 893:	learn: 0.0131046	total: 1.66s	remaining: 197ms
# 894:	learn: 0.0130840	total: 1.67s	remaining: 195ms
# 895:	learn: 0.0130476	total: 1.67s	remaining: 194ms
# 896:	learn: 0.0130273	total: 1.67s	remaining: 192ms
# 897:	learn: 0.0130106	total: 1.67s	remaining: 190ms
# 898:	learn: 0.0129980	total: 1.67s	remaining: 188ms
# 899:	learn: 0.0129711	total: 1.67s	remaining: 186ms
# 900:	learn: 0.0129462	total: 1.68s	remaining: 184ms
# 901:	learn: 0.0129246	total: 1.68s	remaining: 182ms
# 902:	learn: 0.0128981	total: 1.68s	remaining: 180ms
# 903:	learn: 0.0128845	total: 1.68s	remaining: 179ms
# 904:	learn: 0.0128529	total: 1.68s	remaining: 177ms
# 905:	learn: 0.0127967	total: 1.68s	remaining: 175ms
# 906:	learn: 0.0127745	total: 1.69s	remaining: 173ms
# 907:	learn: 0.0127549	total: 1.69s	remaining: 171ms
# 908:	learn: 0.0127406	total: 1.69s	remaining: 169ms
# 909:	learn: 0.0127298	total: 1.69s	remaining: 167ms
# 910:	learn: 0.0127026	total: 1.69s	remaining: 165ms
# 911:	learn: 0.0126826	total: 1.69s	remaining: 163ms
# 912:	learn: 0.0126698	total: 1.7s	remaining: 162ms
# 913:	learn: 0.0126569	total: 1.7s	remaining: 160ms
# 914:	learn: 0.0126302	total: 1.7s	remaining: 158ms
# 915:	learn: 0.0126140	total: 1.7s	remaining: 156ms
# 916:	learn: 0.0125970	total: 1.7s	remaining: 154ms
# 917:	learn: 0.0125771	total: 1.7s	remaining: 152ms
# 918:	learn: 0.0125769	total: 1.71s	remaining: 150ms
# 919:	learn: 0.0125649	total: 1.71s	remaining: 148ms
# 920:	learn: 0.0125389	total: 1.71s	remaining: 147ms
# 921:	learn: 0.0125134	total: 1.71s	remaining: 145ms
# 922:	learn: 0.0125133	total: 1.71s	remaining: 143ms
# 923:	learn: 0.0124991	total: 1.71s	remaining: 141ms
# 924:	learn: 0.0124797	total: 1.72s	remaining: 139ms
# 925:	learn: 0.0124548	total: 1.72s	remaining: 137ms
# 926:	learn: 0.0124470	total: 1.72s	remaining: 135ms
# 927:	learn: 0.0124209	total: 1.72s	remaining: 133ms
# 928:	learn: 0.0123938	total: 1.72s	remaining: 132ms
# 929:	learn: 0.0123758	total: 1.72s	remaining: 130ms
# 930:	learn: 0.0123500	total: 1.73s	remaining: 128ms
# 931:	learn: 0.0123329	total: 1.73s	remaining: 126ms
# 932:	learn: 0.0123066	total: 1.73s	remaining: 124ms
# 933:	learn: 0.0122819	total: 1.73s	remaining: 122ms
# 934:	learn: 0.0122625	total: 1.73s	remaining: 120ms
# 935:	learn: 0.0122265	total: 1.73s	remaining: 119ms
# 936:	learn: 0.0122066	total: 1.74s	remaining: 117ms
# 937:	learn: 0.0121818	total: 1.74s	remaining: 115ms
# 938:	learn: 0.0121544	total: 1.74s	remaining: 113ms
# 939:	learn: 0.0121427	total: 1.74s	remaining: 111ms
# 940:	learn: 0.0121273	total: 1.74s	remaining: 109ms
# 941:	learn: 0.0121208	total: 1.74s	remaining: 107ms
# 942:	learn: 0.0120995	total: 1.75s	remaining: 106ms
# 943:	learn: 0.0120694	total: 1.75s	remaining: 104ms
# 944:	learn: 0.0120538	total: 1.75s	remaining: 102ms
# 945:	learn: 0.0120298	total: 1.75s	remaining: 100ms
# 946:	learn: 0.0120222	total: 1.75s	remaining: 98.1ms
# 947:	learn: 0.0119949	total: 1.75s	remaining: 96.2ms
# 948:	learn: 0.0119567	total: 1.76s	remaining: 94.4ms
# 949:	learn: 0.0119382	total: 1.76s	remaining: 92.5ms
# 950:	learn: 0.0119166	total: 1.76s	remaining: 90.7ms
# 951:	learn: 0.0118981	total: 1.76s	remaining: 88.8ms
# 952:	learn: 0.0118620	total: 1.76s	remaining: 87ms
# 953:	learn: 0.0118291	total: 1.76s	remaining: 85.1ms
# 954:	learn: 0.0118038	total: 1.77s	remaining: 83.2ms
# 955:	learn: 0.0117676	total: 1.77s	remaining: 81.4ms
# 956:	learn: 0.0117540	total: 1.77s	remaining: 79.5ms
# 957:	learn: 0.0117361	total: 1.77s	remaining: 77.7ms
# 958:	learn: 0.0117248	total: 1.77s	remaining: 75.8ms
# 959:	learn: 0.0116981	total: 1.78s	remaining: 74ms
# 960:	learn: 0.0116777	total: 1.78s	remaining: 72.2ms
# 961:	learn: 0.0116598	total: 1.78s	remaining: 70.3ms
# 962:	learn: 0.0116417	total: 1.78s	remaining: 68.5ms
# 963:	learn: 0.0116308	total: 1.78s	remaining: 66.7ms
# 964:	learn: 0.0116137	total: 1.79s	remaining: 64.8ms
# 965:	learn: 0.0116010	total: 1.79s	remaining: 63ms
# 966:	learn: 0.0115947	total: 1.79s	remaining: 61.2ms
# 967:	learn: 0.0115795	total: 1.79s	remaining: 59.4ms
# 968:	learn: 0.0115742	total: 1.8s	remaining: 57.5ms
# 969:	learn: 0.0115513	total: 1.8s	remaining: 55.7ms
# 970:	learn: 0.0115183	total: 1.8s	remaining: 53.8ms
# 971:	learn: 0.0115054	total: 1.8s	remaining: 52ms
# 972:	learn: 0.0114904	total: 1.81s	remaining: 50.2ms
# 973:	learn: 0.0114825	total: 1.81s	remaining: 48.3ms
# 974:	learn: 0.0114613	total: 1.81s	remaining: 46.5ms
# 975:	learn: 0.0114512	total: 1.81s	remaining: 44.6ms
# 976:	learn: 0.0114450	total: 1.82s	remaining: 42.8ms
# 977:	learn: 0.0114420	total: 1.82s	remaining: 40.9ms
# 978:	learn: 0.0114388	total: 1.82s	remaining: 39ms
# 979:	learn: 0.0114235	total: 1.82s	remaining: 37.2ms
# 980:	learn: 0.0113914	total: 1.82s	remaining: 35.3ms
# 981:	learn: 0.0113708	total: 1.82s	remaining: 33.5ms
# 982:	learn: 0.0113471	total: 1.83s	remaining: 31.6ms
# 983:	learn: 0.0113361	total: 1.83s	remaining: 29.8ms
# 984:	learn: 0.0113260	total: 1.83s	remaining: 27.9ms
# 985:	learn: 0.0113116	total: 1.83s	remaining: 26.1ms
# 986:	learn: 0.0112852	total: 1.84s	remaining: 24.2ms
# 987:	learn: 0.0112688	total: 1.84s	remaining: 22.3ms
# 988:	learn: 0.0112532	total: 1.84s	remaining: 20.5ms
# 989:	learn: 0.0112291	total: 1.84s	remaining: 18.6ms
# 990:	learn: 0.0112124	total: 1.84s	remaining: 16.8ms
# 991:	learn: 0.0111894	total: 1.85s	remaining: 14.9ms
# 992:	learn: 0.0111552	total: 1.85s	remaining: 13ms
# 993:	learn: 0.0111419	total: 1.85s	remaining: 11.2ms
# 994:	learn: 0.0111330	total: 1.85s	remaining: 9.31ms
# 995:	learn: 0.0111144	total: 1.85s	remaining: 7.45ms
# 996:	learn: 0.0110875	total: 1.86s	remaining: 5.59ms
# 997:	learn: 0.0110613	total: 1.86s	remaining: 3.73ms
# 998:	learn: 0.0110437	total: 1.86s	remaining: 1.86ms
# 999:	learn: 0.0110230	total: 1.86s	remaining: 0us
# The confusion matrix is [[997  33]
#  [118 261]]
#               precision    recall  f1-score      support
# 0              0.894170  0.967961  0.929604  1030.000000
# 1              0.887755  0.688654  0.775632   379.000000
# accuracy       0.892832  0.892832  0.892832     0.892832
# macro avg      0.890963  0.828308  0.852618  1409.000000
# weighted avg   0.892445  0.892832  0.888187  1409.000000
#           train  test
# Accuracy    1.0  0.89
# ROC AUC     1.0  0.92

# %%
dir(best_cb_model)
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_base_calc_leaf_indexes',
#  '_base_drop_unused_features',
#  '_base_eval_metrics',
#  '_base_predict',
#  '_base_shrink',
#  '_base_virtual_ensembles_predict',
#  '_calc_fstr',
#  '_calc_leaf_indexes',
#  '_calc_ostr',
#  '_check_is_compatible_loss',
#  '_convert_to_asymmetric_representation',
#  '_deserialize_model',
#  '_estimator_type',
#  '_eval_metrics',
#  '_fit',
#  '_get_borders',
#  '_get_cat_feature_indices',
#  '_get_embedding_feature_indices',
#  '_get_float_feature_indices',
#  '_get_nan_treatments',
#  '_get_params',
#  '_get_tags',
#  '_get_text_feature_indices',
#  '_get_tree_leaf_values',
#  '_get_tree_node_to_leaf',
#  '_get_tree_splits',
#  '_get_tree_step_nodes',
#  '_init_params',
#  '_is_classification_objective',
#  '_is_comparable_to',
#  '_is_fitted_',
#  '_is_multiregression_objective',
#  '_is_multitarget_objective',
#  '_is_ranking_objective',
#  '_is_regression_objective',
#  '_is_survivalregression_objective',
#  '_iterate_leaf_indexes',
#  '_leaf_indexes_iterator',
#  '_learning_rate',
#  '_load_from_stream',
#  '_load_from_string',
#  '_load_model',
#  '_n_features_in',
#  '_object',
#  '_plot_nonsymmetric_tree',
#  '_plot_oblivious_tree',
#  '_predict',
#  '_prediction_values_change',
#  '_prepare_train_params',
#  '_process_predict_input_data',
#  '_random_seed',
#  '_save_borders',
#  '_save_model',
#  '_serialize_model',
#  '_set_test_evals',
#  '_set_trained_model_attributes',
#  '_staged_predict',
#  '_staged_predict_iterator',
#  '_sum_models',
#  '_train',
#  '_tree_count',
#  '_tune_hyperparams',
#  '_validate_prediction_type',
#  '_virtual_ensembles_predict',
#  'best_iteration_',
#  'best_score_',
#  'calc_feature_statistics',
#  'calc_leaf_indexes',
#  'classes_',
#  'compare',
#  'copy',
#  'create_metric_calcer',
#  'drop_unused_features',
#  'eval_metrics',
#  'evals_result_',
#  'feature_importances_',
#  'feature_names_',
#  'fit',
#  'get_all_params',
#  'get_best_iteration',
#  'get_best_score',
#  'get_borders',
#  'get_cat_feature_indices',
#  'get_embedding_feature_indices',
#  'get_evals_result',
#  'get_feature_importance',
#  'get_leaf_values',
#  'get_leaf_weights',
#  'get_metadata',
#  'get_n_features_in',
#  'get_object_importance',
#  'get_param',
#  'get_params',
#  'get_probability_threshold',
#  'get_scale_and_bias',
#  'get_test_eval',
#  'get_test_evals',
#  'get_text_feature_indices',
#  'get_tree_leaf_counts',
#  'grid_search',
#  'is_fitted',
#  'iterate_leaf_indexes',
#  'learning_rate_',
#  'load_model',
#  'n_features_in_',
#  'plot_partial_dependence',
#  'plot_predictions',
#  'plot_tree',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'random_seed_',
#  'randomized_search',
#  'save_borders',
#  'save_model',
#  'score',
#  'select_features',
#  'set_feature_names',
#  'set_leaf_values',
#  'set_params',
#  'set_probability_threshold',
#  'set_scale_and_bias',
#  'shrink',
#  'staged_predict',
#  'staged_predict_log_proba',
#  'staged_predict_proba',
#  'tree_count_',
#  'virtual_ensembles_predict']

# %%
best_cb_model.get_params()
# Out:
# {'iterations': 400,
#  'learning_rate': 0.2,
#  'loss_function': 'Logloss',
#  'random_seed': 42}

# %%
model_results_df = pd.DataFrame({'model': ["best_dc_model",
    'LogisticRegression', 
                                           'RandomForestClassifier',
                                           'CatBoostClassifier',
                                           ],
              'best_ROC-AUC': [best_dc_auc, best_lr_auc,  best_rf_auc,  best_cb_auc
                          ],
              'train_time': [best_dc_time, best_lr_time,  best_rf_time,  best_cb_time
                            ],
               'details of final finetuned model using gridsearch and ROC-AUC scorer':  [ DummyClassifier(), best_lr_model, 
                      "RandomForestClassifier(class_weight='balanced', max_depth=9, n_estimators=500,random_state=42)", 
                               "CatBoostClassifiercatboost(iterations= 400, learning_rate = 0.2, loss_funtion = 'Logloss', random_seed: 42)"]   })

# %%
model_results_df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_fda42_row0_col0, #T_fda42_row0_col1, #T_fda42_row0_col2, #T_fda42_row0_col3, #T_fda42_row1_col0, #T_fda42_row1_col1, #T_fda42_row1_col2, #T_fda42_row1_col3, #T_fda42_row2_col0, #T_fda42_row2_col1, #T_fda42_row2_col2, #T_fda42_row2_col3, #T_fda42_row3_col0, #T_fda42_row3_col1, #T_fda42_row3_col2, #T_fda42_row3_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_fda42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda42_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_fda42_level0_col1" class="col_heading level0 col1" >best_ROC-AUC</th>
#       <th id="T_fda42_level0_col2" class="col_heading level0 col2" >train_time</th>
#       <th id="T_fda42_level0_col3" class="col_heading level0 col3" >details of final finetuned model using gridsearch and ROC-AUC scorer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fda42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fda42_row0_col0" class="data row0 col0" >best_dc_model</td>
#       <td id="T_fda42_row0_col1" class="data row0 col1" >0.500000</td>
#       <td id="T_fda42_row0_col2" class="data row0 col2" >0.020000</td>
#       <td id="T_fda42_row0_col3" class="data row0 col3" >DummyClassifier()</td>
#     </tr>
#     <tr>
#       <th id="T_fda42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fda42_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_fda42_row1_col1" class="data row1 col1" >0.845459</td>
#       <td id="T_fda42_row1_col2" class="data row1 col2" >0.520000</td>
#       <td id="T_fda42_row1_col3" class="data row1 col3" >LogisticRegression(C=1, class_weight='balanced', random_state=42)</td>
#     </tr>
#     <tr>
#       <th id="T_fda42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fda42_row2_col0" class="data row2 col0" >RandomForestClassifier</td>
#       <td id="T_fda42_row2_col1" class="data row2 col1" >0.884978</td>
#       <td id="T_fda42_row2_col2" class="data row2 col2" >133.850000</td>
#       <td id="T_fda42_row2_col3" class="data row2 col3" >RandomForestClassifier(class_weight='balanced', max_depth=9, n_estimators=500,random_state=42)</td>
#     </tr>
#     <tr>
#       <th id="T_fda42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fda42_row3_col0" class="data row3 col0" >CatBoostClassifier</td>
#       <td id="T_fda42_row3_col1" class="data row3 col1" >0.919848</td>
#       <td id="T_fda42_row3_col2" class="data row3 col2" >21.310000</td>
#       <td id="T_fda42_row3_col3" class="data row3 col3" >CatBoostClassifiercatboost(iterations= 400, learning_rate = 0.2, loss_funtion = 'Logloss', random_seed: 42)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observations
#
# - The best model in terms of ROC-AUC is the catboost model.  In addition, its training time is optimal.
# - The precision, recall and F1 of this model are all at 89 compared to 85 for the random forest.

# %%
# best features from rf model
pd.DataFrame(best_cb_model.feature_importances_, index=X_train.columns.tolist()).sort_values(0, ascending=False)
# Out:
#                                                 0
# total_charges                           23.672362
# days_of_service                         18.254633
# monthly_charges                         14.752317
# month                                    7.320905
# type_Two year                            3.696011
# internet_service_Fiber optic             3.249970
# year                                     2.976121
# day_of_week                              2.559471
# services                                 2.127120
# dependents                               1.975843
# paperless_billing_Yes                    1.789611
# gender_Male                              1.759989
# type_One year                            1.646422
# payment_method_Electronic check          1.537293
# multiple_lines                           1.467862
# internet_service_No Service              1.352847
# senior_citizen                           1.237180
# tech_support                             1.195832
# online_security                          1.163364
# online_backup                            1.132369
# partner                                  1.035021
# streaming_tv                             0.984444
# payment_method_Mailed check              0.928157
# streaming_movies                         0.840248
# device_protection                        0.787095
# payment_method_Credit card (automatic)   0.557513

# %% [markdown]
# Observations
#
# - The order and magnitude of importance of the variables above shifted. The three related, but distinct variables total_charges, days_of_service, monthly_charges climbed to the top of the list with days_of_service slightly decreasing in importance. Type_two_year_contract and internet_service_fiber_optic remained very important. Month and year remained in the top 10 most important features. New feature that became more relevant are day of the week and services.  This is not surprising since we originally normalization of the bar plot above showed their explanatory power.

# %% [markdown]
# ## Testing the performance of the chosen model

# %%
cat = CatBoostClassifier(learning_rate=0.2, loss_function='Logloss', iterations = 400,
                        random_seed=42)

cat.fit(X_train, y_train)
y_pred = cat.predict(X_test)

print("The confusion matrix is", confusion_matrix(y_test, y_pred))

display_classification_report(y_test, y_pred)
result = evaluate_model(cat, X_train, y_train, X_test, y_test);
# Out:
# 0:	learn: 0.5798484	total: 2.26ms	remaining: 903ms
# 1:	learn: 0.5240339	total: 5.49ms	remaining: 1.09s
# 2:	learn: 0.4751599	total: 8.41ms	remaining: 1.11s
# 3:	learn: 0.4424399	total: 10.7ms	remaining: 1.06s
# 4:	learn: 0.4232643	total: 14.3ms	remaining: 1.13s
# 5:	learn: 0.4008260	total: 17ms	remaining: 1.11s
# 6:	learn: 0.3873857	total: 19.4ms	remaining: 1.09s
# 7:	learn: 0.3800876	total: 22.8ms	remaining: 1.12s
# 8:	learn: 0.3747905	total: 25.6ms	remaining: 1.11s
# 9:	learn: 0.3686450	total: 28.8ms	remaining: 1.12s
# 10:	learn: 0.3657421	total: 31.3ms	remaining: 1.1s
# 11:	learn: 0.3590254	total: 33.6ms	remaining: 1.09s
# 12:	learn: 0.3546356	total: 36.4ms	remaining: 1.08s
# 13:	learn: 0.3531145	total: 40ms	remaining: 1.1s
# 14:	learn: 0.3500281	total: 45.6ms	remaining: 1.17s
# 15:	learn: 0.3469170	total: 52.5ms	remaining: 1.26s
# 16:	learn: 0.3403561	total: 62ms	remaining: 1.4s
# 17:	learn: 0.3361766	total: 66ms	remaining: 1.4s
# 18:	learn: 0.3332431	total: 69.3ms	remaining: 1.39s
# 19:	learn: 0.3317966	total: 73ms	remaining: 1.39s
# 20:	learn: 0.3291447	total: 77.3ms	remaining: 1.4s
# 21:	learn: 0.3254379	total: 80.6ms	remaining: 1.38s
# 22:	learn: 0.3206313	total: 83.4ms	remaining: 1.37s
# 23:	learn: 0.3192036	total: 89ms	remaining: 1.39s
# 24:	learn: 0.3169085	total: 93.1ms	remaining: 1.4s
# 25:	learn: 0.3133186	total: 96.6ms	remaining: 1.39s
# 26:	learn: 0.3110036	total: 98.6ms	remaining: 1.36s
# 27:	learn: 0.3064834	total: 100ms	remaining: 1.33s
# 28:	learn: 0.3027672	total: 102ms	remaining: 1.31s
# 29:	learn: 0.3012298	total: 104ms	remaining: 1.28s
# 30:	learn: 0.2996596	total: 105ms	remaining: 1.25s
# 31:	learn: 0.2973269	total: 108ms	remaining: 1.24s
# 32:	learn: 0.2960320	total: 110ms	remaining: 1.22s
# 33:	learn: 0.2928606	total: 111ms	remaining: 1.2s
# 34:	learn: 0.2898679	total: 113ms	remaining: 1.18s
# 35:	learn: 0.2871846	total: 115ms	remaining: 1.16s
# 36:	learn: 0.2843910	total: 117ms	remaining: 1.14s
# 37:	learn: 0.2822723	total: 118ms	remaining: 1.13s
# 38:	learn: 0.2801450	total: 120ms	remaining: 1.11s
# 39:	learn: 0.2781210	total: 122ms	remaining: 1.1s
# 40:	learn: 0.2761644	total: 124ms	remaining: 1.08s
# 41:	learn: 0.2746064	total: 126ms	remaining: 1.08s
# 42:	learn: 0.2727387	total: 128ms	remaining: 1.06s
# 43:	learn: 0.2709388	total: 130ms	remaining: 1.05s
# 44:	learn: 0.2680303	total: 131ms	remaining: 1.03s
# 45:	learn: 0.2662322	total: 133ms	remaining: 1.02s
# 46:	learn: 0.2634561	total: 135ms	remaining: 1.01s
# 47:	learn: 0.2610876	total: 137ms	remaining: 1s
# 48:	learn: 0.2584862	total: 139ms	remaining: 993ms
# 49:	learn: 0.2567988	total: 141ms	remaining: 984ms
# 50:	learn: 0.2545085	total: 142ms	remaining: 973ms
# 51:	learn: 0.2523328	total: 144ms	remaining: 963ms
# 52:	learn: 0.2505951	total: 145ms	remaining: 953ms
# 53:	learn: 0.2492704	total: 147ms	remaining: 944ms
# 54:	learn: 0.2465690	total: 149ms	remaining: 935ms
# 55:	learn: 0.2445095	total: 151ms	remaining: 926ms
# 56:	learn: 0.2417669	total: 152ms	remaining: 916ms
# 57:	learn: 0.2397779	total: 154ms	remaining: 910ms
# 58:	learn: 0.2369278	total: 156ms	remaining: 904ms
# 59:	learn: 0.2344220	total: 158ms	remaining: 897ms
# 60:	learn: 0.2325809	total: 160ms	remaining: 890ms
# 61:	learn: 0.2309060	total: 162ms	remaining: 882ms
# 62:	learn: 0.2289214	total: 164ms	remaining: 876ms
# 63:	learn: 0.2265763	total: 165ms	remaining: 869ms
# 64:	learn: 0.2252455	total: 168ms	remaining: 864ms
# 65:	learn: 0.2237977	total: 170ms	remaining: 860ms
# 66:	learn: 0.2226093	total: 172ms	remaining: 855ms
# 67:	learn: 0.2202815	total: 174ms	remaining: 851ms
# 68:	learn: 0.2183305	total: 177ms	remaining: 848ms
# 69:	learn: 0.2171100	total: 179ms	remaining: 846ms
# 70:	learn: 0.2161024	total: 182ms	remaining: 843ms
# 71:	learn: 0.2149015	total: 185ms	remaining: 841ms
# 72:	learn: 0.2132484	total: 188ms	remaining: 841ms
# 73:	learn: 0.2111572	total: 190ms	remaining: 839ms
# 74:	learn: 0.2096704	total: 193ms	remaining: 835ms
# 75:	learn: 0.2080357	total: 195ms	remaining: 832ms
# 76:	learn: 0.2072301	total: 197ms	remaining: 827ms
# 77:	learn: 0.2060296	total: 199ms	remaining: 822ms
# 78:	learn: 0.2046069	total: 201ms	remaining: 818ms
# 79:	learn: 0.2035572	total: 205ms	remaining: 818ms
# 80:	learn: 0.2015354	total: 208ms	remaining: 819ms
# 81:	learn: 0.2005779	total: 211ms	remaining: 817ms
# 82:	learn: 0.1992225	total: 215ms	remaining: 821ms
# 83:	learn: 0.1980470	total: 217ms	remaining: 817ms
# 84:	learn: 0.1966443	total: 220ms	remaining: 814ms
# 85:	learn: 0.1951737	total: 222ms	remaining: 810ms
# 86:	learn: 0.1940276	total: 224ms	remaining: 806ms
# 87:	learn: 0.1925657	total: 226ms	remaining: 803ms
# 88:	learn: 0.1912887	total: 230ms	remaining: 803ms
# 89:	learn: 0.1901822	total: 232ms	remaining: 801ms
# 90:	learn: 0.1886879	total: 235ms	remaining: 798ms
# 91:	learn: 0.1874180	total: 237ms	remaining: 793ms
# 92:	learn: 0.1863793	total: 238ms	remaining: 787ms
# 93:	learn: 0.1851027	total: 240ms	remaining: 781ms
# 94:	learn: 0.1840511	total: 242ms	remaining: 776ms
# 95:	learn: 0.1833154	total: 243ms	remaining: 771ms
# 96:	learn: 0.1826568	total: 245ms	remaining: 766ms
# 97:	learn: 0.1814940	total: 247ms	remaining: 761ms
# 98:	learn: 0.1806459	total: 249ms	remaining: 756ms
# 99:	learn: 0.1793048	total: 250ms	remaining: 751ms
# 100:	learn: 0.1782864	total: 252ms	remaining: 747ms
# 101:	learn: 0.1772120	total: 254ms	remaining: 742ms
# 102:	learn: 0.1760695	total: 256ms	remaining: 737ms
# 103:	learn: 0.1749516	total: 257ms	remaining: 732ms
# 104:	learn: 0.1736751	total: 259ms	remaining: 727ms
# 105:	learn: 0.1720669	total: 261ms	remaining: 724ms
# 106:	learn: 0.1709512	total: 263ms	remaining: 719ms
# 107:	learn: 0.1701270	total: 264ms	remaining: 714ms
# 108:	learn: 0.1690326	total: 266ms	remaining: 710ms
# 109:	learn: 0.1679582	total: 267ms	remaining: 705ms
# 110:	learn: 0.1670144	total: 269ms	remaining: 701ms
# 111:	learn: 0.1661161	total: 271ms	remaining: 697ms
# 112:	learn: 0.1650400	total: 273ms	remaining: 693ms
# 113:	learn: 0.1639970	total: 274ms	remaining: 688ms
# 114:	learn: 0.1630601	total: 276ms	remaining: 684ms
# 115:	learn: 0.1621593	total: 278ms	remaining: 680ms
# 116:	learn: 0.1606445	total: 280ms	remaining: 677ms
# 117:	learn: 0.1590566	total: 281ms	remaining: 673ms
# 118:	learn: 0.1586993	total: 283ms	remaining: 669ms
# 119:	learn: 0.1579347	total: 285ms	remaining: 665ms
# 120:	learn: 0.1569064	total: 286ms	remaining: 661ms
# 121:	learn: 0.1562267	total: 288ms	remaining: 657ms
# 122:	learn: 0.1556189	total: 290ms	remaining: 653ms
# 123:	learn: 0.1548399	total: 292ms	remaining: 650ms
# 124:	learn: 0.1541770	total: 294ms	remaining: 646ms
# 125:	learn: 0.1533196	total: 295ms	remaining: 642ms
# 126:	learn: 0.1520672	total: 297ms	remaining: 638ms
# 127:	learn: 0.1510504	total: 298ms	remaining: 634ms
# 128:	learn: 0.1503551	total: 300ms	remaining: 631ms
# 129:	learn: 0.1495964	total: 302ms	remaining: 627ms
# 130:	learn: 0.1486157	total: 303ms	remaining: 623ms
# 131:	learn: 0.1474564	total: 305ms	remaining: 619ms
# 132:	learn: 0.1463388	total: 307ms	remaining: 616ms
# 133:	learn: 0.1453352	total: 308ms	remaining: 612ms
# 134:	learn: 0.1446116	total: 310ms	remaining: 608ms
# 135:	learn: 0.1437032	total: 311ms	remaining: 605ms
# 136:	learn: 0.1431296	total: 313ms	remaining: 601ms
# 137:	learn: 0.1422836	total: 315ms	remaining: 597ms
# 138:	learn: 0.1414780	total: 316ms	remaining: 594ms
# 139:	learn: 0.1405069	total: 318ms	remaining: 591ms
# 140:	learn: 0.1399067	total: 320ms	remaining: 587ms
# 141:	learn: 0.1393379	total: 321ms	remaining: 584ms
# 142:	learn: 0.1385913	total: 323ms	remaining: 580ms
# 143:	learn: 0.1377774	total: 325ms	remaining: 577ms
# 144:	learn: 0.1368938	total: 326ms	remaining: 574ms
# 145:	learn: 0.1364150	total: 328ms	remaining: 570ms
# 146:	learn: 0.1357393	total: 330ms	remaining: 567ms
# 147:	learn: 0.1348163	total: 331ms	remaining: 564ms
# 148:	learn: 0.1340620	total: 333ms	remaining: 561ms
# 149:	learn: 0.1333920	total: 335ms	remaining: 558ms
# 150:	learn: 0.1328623	total: 336ms	remaining: 555ms
# 151:	learn: 0.1321145	total: 338ms	remaining: 551ms
# 152:	learn: 0.1311876	total: 340ms	remaining: 549ms
# 153:	learn: 0.1300733	total: 343ms	remaining: 547ms
# 154:	learn: 0.1294145	total: 344ms	remaining: 544ms
# 155:	learn: 0.1285656	total: 346ms	remaining: 541ms
# 156:	learn: 0.1279160	total: 348ms	remaining: 539ms
# 157:	learn: 0.1271747	total: 350ms	remaining: 536ms
# 158:	learn: 0.1266930	total: 352ms	remaining: 534ms
# 159:	learn: 0.1261660	total: 354ms	remaining: 531ms
# 160:	learn: 0.1254905	total: 356ms	remaining: 528ms
# 161:	learn: 0.1250444	total: 357ms	remaining: 525ms
# 162:	learn: 0.1244993	total: 359ms	remaining: 522ms
# 163:	learn: 0.1240237	total: 361ms	remaining: 519ms
# 164:	learn: 0.1235385	total: 363ms	remaining: 516ms
# 165:	learn: 0.1227504	total: 365ms	remaining: 514ms
# 166:	learn: 0.1221784	total: 368ms	remaining: 513ms
# 167:	learn: 0.1219806	total: 374ms	remaining: 516ms
# 168:	learn: 0.1213231	total: 377ms	remaining: 516ms
# 169:	learn: 0.1206938	total: 379ms	remaining: 513ms
# 170:	learn: 0.1202721	total: 382ms	remaining: 511ms
# 171:	learn: 0.1193898	total: 384ms	remaining: 509ms
# 172:	learn: 0.1191721	total: 386ms	remaining: 507ms
# 173:	learn: 0.1184594	total: 389ms	remaining: 505ms
# 174:	learn: 0.1177864	total: 391ms	remaining: 502ms
# 175:	learn: 0.1176079	total: 393ms	remaining: 500ms
# 176:	learn: 0.1168706	total: 395ms	remaining: 498ms
# 177:	learn: 0.1161529	total: 398ms	remaining: 496ms
# 178:	learn: 0.1156078	total: 400ms	remaining: 494ms
# 179:	learn: 0.1151808	total: 402ms	remaining: 491ms
# 180:	learn: 0.1144173	total: 405ms	remaining: 489ms
# 181:	learn: 0.1139426	total: 408ms	remaining: 488ms
# 182:	learn: 0.1134804	total: 410ms	remaining: 486ms
# 183:	learn: 0.1123729	total: 412ms	remaining: 484ms
# 184:	learn: 0.1116380	total: 415ms	remaining: 482ms
# 185:	learn: 0.1109306	total: 417ms	remaining: 480ms
# 186:	learn: 0.1104741	total: 419ms	remaining: 478ms
# 187:	learn: 0.1098418	total: 422ms	remaining: 476ms
# 188:	learn: 0.1092525	total: 425ms	remaining: 475ms
# 189:	learn: 0.1089574	total: 428ms	remaining: 473ms
# 190:	learn: 0.1084612	total: 429ms	remaining: 470ms
# 191:	learn: 0.1080979	total: 431ms	remaining: 467ms
# 192:	learn: 0.1074847	total: 433ms	remaining: 465ms
# 193:	learn: 0.1070945	total: 435ms	remaining: 462ms
# 194:	learn: 0.1067694	total: 440ms	remaining: 462ms
# 195:	learn: 0.1061580	total: 443ms	remaining: 461ms
# 196:	learn: 0.1060058	total: 445ms	remaining: 459ms
# 197:	learn: 0.1056036	total: 449ms	remaining: 458ms
# 198:	learn: 0.1051791	total: 453ms	remaining: 457ms
# 199:	learn: 0.1043733	total: 455ms	remaining: 455ms
# 200:	learn: 0.1040206	total: 457ms	remaining: 452ms
# 201:	learn: 0.1034860	total: 458ms	remaining: 449ms
# 202:	learn: 0.1029852	total: 461ms	remaining: 447ms
# 203:	learn: 0.1026122	total: 464ms	remaining: 446ms
# 204:	learn: 0.1022691	total: 466ms	remaining: 443ms
# 205:	learn: 0.1017317	total: 468ms	remaining: 441ms
# 206:	learn: 0.1010666	total: 470ms	remaining: 438ms
# 207:	learn: 0.1006037	total: 472ms	remaining: 436ms
# 208:	learn: 0.1001502	total: 474ms	remaining: 433ms
# 209:	learn: 0.0996307	total: 476ms	remaining: 431ms
# 210:	learn: 0.0991680	total: 478ms	remaining: 428ms
# 211:	learn: 0.0986472	total: 480ms	remaining: 426ms
# 212:	learn: 0.0983495	total: 482ms	remaining: 423ms
# 213:	learn: 0.0979905	total: 484ms	remaining: 421ms
# 214:	learn: 0.0974339	total: 486ms	remaining: 418ms
# 215:	learn: 0.0968639	total: 488ms	remaining: 416ms
# 216:	learn: 0.0964809	total: 490ms	remaining: 414ms
# 217:	learn: 0.0958803	total: 493ms	remaining: 411ms
# 218:	learn: 0.0955692	total: 494ms	remaining: 409ms
# 219:	learn: 0.0952540	total: 496ms	remaining: 406ms
# 220:	learn: 0.0944758	total: 498ms	remaining: 404ms
# 221:	learn: 0.0939032	total: 500ms	remaining: 401ms
# 222:	learn: 0.0934134	total: 502ms	remaining: 399ms
# 223:	learn: 0.0929316	total: 504ms	remaining: 396ms
# 224:	learn: 0.0923488	total: 506ms	remaining: 394ms
# 225:	learn: 0.0918121	total: 508ms	remaining: 391ms
# 226:	learn: 0.0914753	total: 510ms	remaining: 389ms
# 227:	learn: 0.0910762	total: 512ms	remaining: 386ms
# 228:	learn: 0.0905784	total: 514ms	remaining: 384ms
# 229:	learn: 0.0900237	total: 516ms	remaining: 381ms
# 230:	learn: 0.0893371	total: 517ms	remaining: 379ms
# 231:	learn: 0.0890707	total: 519ms	remaining: 376ms
# 232:	learn: 0.0887267	total: 522ms	remaining: 374ms
# 233:	learn: 0.0883132	total: 524ms	remaining: 371ms
# 234:	learn: 0.0878136	total: 526ms	remaining: 369ms
# 235:	learn: 0.0874970	total: 527ms	remaining: 367ms
# 236:	learn: 0.0871539	total: 529ms	remaining: 364ms
# 237:	learn: 0.0867951	total: 531ms	remaining: 362ms
# 238:	learn: 0.0863137	total: 533ms	remaining: 359ms
# 239:	learn: 0.0858559	total: 535ms	remaining: 357ms
# 240:	learn: 0.0853241	total: 537ms	remaining: 354ms
# 241:	learn: 0.0849843	total: 539ms	remaining: 352ms
# 242:	learn: 0.0847154	total: 541ms	remaining: 350ms
# 243:	learn: 0.0844405	total: 543ms	remaining: 347ms
# 244:	learn: 0.0841191	total: 546ms	remaining: 345ms
# 245:	learn: 0.0836825	total: 548ms	remaining: 343ms
# 246:	learn: 0.0834628	total: 550ms	remaining: 341ms
# 247:	learn: 0.0829227	total: 553ms	remaining: 339ms
# 248:	learn: 0.0825468	total: 555ms	remaining: 337ms
# 249:	learn: 0.0821662	total: 557ms	remaining: 334ms
# 250:	learn: 0.0817165	total: 560ms	remaining: 333ms
# 251:	learn: 0.0814479	total: 562ms	remaining: 330ms
# 252:	learn: 0.0809193	total: 565ms	remaining: 328ms
# 253:	learn: 0.0806977	total: 567ms	remaining: 326ms
# 254:	learn: 0.0801958	total: 570ms	remaining: 324ms
# 255:	learn: 0.0798825	total: 572ms	remaining: 322ms
# 256:	learn: 0.0795944	total: 574ms	remaining: 319ms
# 257:	learn: 0.0792734	total: 576ms	remaining: 317ms
# 258:	learn: 0.0789616	total: 577ms	remaining: 314ms
# 259:	learn: 0.0786806	total: 579ms	remaining: 312ms
# 260:	learn: 0.0782937	total: 581ms	remaining: 309ms
# 261:	learn: 0.0780628	total: 582ms	remaining: 307ms
# 262:	learn: 0.0777957	total: 584ms	remaining: 304ms
# 263:	learn: 0.0773867	total: 585ms	remaining: 302ms
# 264:	learn: 0.0771030	total: 587ms	remaining: 299ms
# 265:	learn: 0.0769652	total: 589ms	remaining: 297ms
# 266:	learn: 0.0766648	total: 591ms	remaining: 294ms
# 267:	learn: 0.0763692	total: 593ms	remaining: 292ms
# 268:	learn: 0.0760209	total: 596ms	remaining: 290ms
# 269:	learn: 0.0756318	total: 599ms	remaining: 288ms
# 270:	learn: 0.0752085	total: 601ms	remaining: 286ms
# 271:	learn: 0.0748676	total: 603ms	remaining: 284ms
# 272:	learn: 0.0745498	total: 605ms	remaining: 281ms
# 273:	learn: 0.0742153	total: 606ms	remaining: 279ms
# 274:	learn: 0.0738172	total: 608ms	remaining: 276ms
# 275:	learn: 0.0734409	total: 610ms	remaining: 274ms
# 276:	learn: 0.0732068	total: 611ms	remaining: 271ms
# 277:	learn: 0.0730983	total: 613ms	remaining: 269ms
# 278:	learn: 0.0728566	total: 615ms	remaining: 267ms
# 279:	learn: 0.0724226	total: 616ms	remaining: 264ms
# 280:	learn: 0.0721874	total: 618ms	remaining: 262ms
# 281:	learn: 0.0718714	total: 620ms	remaining: 259ms
# 282:	learn: 0.0715803	total: 621ms	remaining: 257ms
# 283:	learn: 0.0714253	total: 623ms	remaining: 254ms
# 284:	learn: 0.0712221	total: 625ms	remaining: 252ms
# 285:	learn: 0.0709159	total: 626ms	remaining: 250ms
# 286:	learn: 0.0705199	total: 628ms	remaining: 247ms
# 287:	learn: 0.0701421	total: 630ms	remaining: 245ms
# 288:	learn: 0.0698138	total: 631ms	remaining: 243ms
# 289:	learn: 0.0695871	total: 633ms	remaining: 240ms
# 290:	learn: 0.0692280	total: 635ms	remaining: 238ms
# 291:	learn: 0.0690379	total: 636ms	remaining: 235ms
# 292:	learn: 0.0687207	total: 638ms	remaining: 233ms
# 293:	learn: 0.0684091	total: 639ms	remaining: 231ms
# 294:	learn: 0.0682465	total: 641ms	remaining: 228ms
# 295:	learn: 0.0679789	total: 643ms	remaining: 226ms
# 296:	learn: 0.0676977	total: 644ms	remaining: 223ms
# 297:	learn: 0.0675773	total: 646ms	remaining: 221ms
# 298:	learn: 0.0674068	total: 648ms	remaining: 219ms
# 299:	learn: 0.0668900	total: 649ms	remaining: 216ms
# 300:	learn: 0.0667039	total: 651ms	remaining: 214ms
# 301:	learn: 0.0663493	total: 652ms	remaining: 212ms
# 302:	learn: 0.0659847	total: 654ms	remaining: 209ms
# 303:	learn: 0.0656472	total: 656ms	remaining: 207ms
# 304:	learn: 0.0654325	total: 657ms	remaining: 205ms
# 305:	learn: 0.0652658	total: 659ms	remaining: 202ms
# 306:	learn: 0.0650880	total: 661ms	remaining: 200ms
# 307:	learn: 0.0648069	total: 663ms	remaining: 198ms
# 308:	learn: 0.0644820	total: 664ms	remaining: 196ms
# 309:	learn: 0.0641833	total: 666ms	remaining: 193ms
# 310:	learn: 0.0639443	total: 668ms	remaining: 191ms
# 311:	learn: 0.0636506	total: 669ms	remaining: 189ms
# 312:	learn: 0.0634455	total: 671ms	remaining: 187ms
# 313:	learn: 0.0629312	total: 673ms	remaining: 184ms
# 314:	learn: 0.0626990	total: 674ms	remaining: 182ms
# 315:	learn: 0.0623895	total: 676ms	remaining: 180ms
# 316:	learn: 0.0620907	total: 678ms	remaining: 177ms
# 317:	learn: 0.0618178	total: 680ms	remaining: 175ms
# 318:	learn: 0.0615880	total: 681ms	remaining: 173ms
# 319:	learn: 0.0612923	total: 683ms	remaining: 171ms
# 320:	learn: 0.0610452	total: 684ms	remaining: 168ms
# 321:	learn: 0.0607942	total: 686ms	remaining: 166ms
# 322:	learn: 0.0605233	total: 688ms	remaining: 164ms
# 323:	learn: 0.0602678	total: 690ms	remaining: 162ms
# 324:	learn: 0.0600904	total: 691ms	remaining: 160ms
# 325:	learn: 0.0598592	total: 693ms	remaining: 157ms
# 326:	learn: 0.0596213	total: 695ms	remaining: 155ms
# 327:	learn: 0.0593327	total: 696ms	remaining: 153ms
# 328:	learn: 0.0591602	total: 698ms	remaining: 151ms
# 329:	learn: 0.0590070	total: 699ms	remaining: 148ms
# 330:	learn: 0.0586158	total: 701ms	remaining: 146ms
# 331:	learn: 0.0583507	total: 703ms	remaining: 144ms
# 332:	learn: 0.0579345	total: 704ms	remaining: 142ms
# 333:	learn: 0.0577347	total: 706ms	remaining: 140ms
# 334:	learn: 0.0574575	total: 708ms	remaining: 137ms
# 335:	learn: 0.0571410	total: 709ms	remaining: 135ms
# 336:	learn: 0.0568840	total: 711ms	remaining: 133ms
# 337:	learn: 0.0565266	total: 713ms	remaining: 131ms
# 338:	learn: 0.0562792	total: 715ms	remaining: 129ms
# 339:	learn: 0.0561259	total: 716ms	remaining: 126ms
# 340:	learn: 0.0559218	total: 718ms	remaining: 124ms
# 341:	learn: 0.0557939	total: 720ms	remaining: 122ms
# 342:	learn: 0.0556740	total: 722ms	remaining: 120ms
# 343:	learn: 0.0555847	total: 723ms	remaining: 118ms
# 344:	learn: 0.0554620	total: 725ms	remaining: 116ms
# 345:	learn: 0.0552121	total: 727ms	remaining: 113ms
# 346:	learn: 0.0548974	total: 729ms	remaining: 111ms
# 347:	learn: 0.0547268	total: 731ms	remaining: 109ms
# 348:	learn: 0.0545549	total: 734ms	remaining: 107ms
# 349:	learn: 0.0544381	total: 736ms	remaining: 105ms
# 350:	learn: 0.0542748	total: 738ms	remaining: 103ms
# 351:	learn: 0.0541402	total: 740ms	remaining: 101ms
# 352:	learn: 0.0539394	total: 743ms	remaining: 98.9ms
# 353:	learn: 0.0537618	total: 746ms	remaining: 97ms
# 354:	learn: 0.0535445	total: 750ms	remaining: 95ms
# 355:	learn: 0.0532029	total: 752ms	remaining: 93ms
# 356:	learn: 0.0529611	total: 754ms	remaining: 90.9ms
# 357:	learn: 0.0527074	total: 757ms	remaining: 88.8ms
# 358:	learn: 0.0526292	total: 759ms	remaining: 86.7ms
# 359:	learn: 0.0524598	total: 762ms	remaining: 84.6ms
# 360:	learn: 0.0523479	total: 765ms	remaining: 82.6ms
# 361:	learn: 0.0521345	total: 767ms	remaining: 80.6ms
# 362:	learn: 0.0519154	total: 769ms	remaining: 78.4ms
# 363:	learn: 0.0518042	total: 771ms	remaining: 76.2ms
# 364:	learn: 0.0517223	total: 773ms	remaining: 74.1ms
# 365:	learn: 0.0515658	total: 774ms	remaining: 71.9ms
# 366:	learn: 0.0513469	total: 776ms	remaining: 69.8ms
# 367:	learn: 0.0511047	total: 777ms	remaining: 67.6ms
# 368:	learn: 0.0509358	total: 779ms	remaining: 65.5ms
# 369:	learn: 0.0507660	total: 781ms	remaining: 63.3ms
# 370:	learn: 0.0506171	total: 783ms	remaining: 61.2ms
# 371:	learn: 0.0503550	total: 785ms	remaining: 59.1ms
# 372:	learn: 0.0502098	total: 787ms	remaining: 57ms
# 373:	learn: 0.0500529	total: 789ms	remaining: 54.9ms
# 374:	learn: 0.0498871	total: 791ms	remaining: 52.7ms
# 375:	learn: 0.0495605	total: 793ms	remaining: 50.6ms
# 376:	learn: 0.0493444	total: 794ms	remaining: 48.5ms
# 377:	learn: 0.0491236	total: 796ms	remaining: 46.3ms
# 378:	learn: 0.0489099	total: 798ms	remaining: 44.2ms
# 379:	learn: 0.0487737	total: 800ms	remaining: 42.1ms
# 380:	learn: 0.0485773	total: 801ms	remaining: 40ms
# 381:	learn: 0.0484361	total: 803ms	remaining: 37.8ms
# 382:	learn: 0.0482328	total: 805ms	remaining: 35.7ms
# 383:	learn: 0.0481285	total: 806ms	remaining: 33.6ms
# 384:	learn: 0.0478187	total: 808ms	remaining: 31.5ms
# 385:	learn: 0.0475996	total: 809ms	remaining: 29.4ms
# 386:	learn: 0.0474355	total: 811ms	remaining: 27.2ms
# 387:	learn: 0.0473558	total: 813ms	remaining: 25.1ms
# 388:	learn: 0.0471754	total: 814ms	remaining: 23ms
# 389:	learn: 0.0470952	total: 816ms	remaining: 20.9ms
# 390:	learn: 0.0468819	total: 818ms	remaining: 18.8ms
# 391:	learn: 0.0466827	total: 819ms	remaining: 16.7ms
# 392:	learn: 0.0465885	total: 821ms	remaining: 14.6ms
# 393:	learn: 0.0463535	total: 822ms	remaining: 12.5ms
# 394:	learn: 0.0462133	total: 824ms	remaining: 10.4ms
# 395:	learn: 0.0459949	total: 826ms	remaining: 8.35ms
# 396:	learn: 0.0458773	total: 828ms	remaining: 6.26ms
# 397:	learn: 0.0457282	total: 830ms	remaining: 4.17ms
# 398:	learn: 0.0456490	total: 831ms	remaining: 2.08ms
# 399:	learn: 0.0455194	total: 833ms	remaining: 0us
# The confusion matrix is [[991  29]
#  [115 274]]
#               precision    recall  f1-score    support
# 0              0.896022  0.971569  0.932267  1020.0000
# 1              0.904290  0.704370  0.791908   389.0000
# accuracy       0.897800  0.897800  0.897800     0.8978
# macro avg      0.900156  0.837969  0.862087  1409.0000
# weighted avg   0.898305  0.897800  0.893516  1409.0000
#           train  test
# Accuracy    1.0  0.90
# ROC AUC     1.0  0.92

# %% [markdown]
# ## sanity check

# %%
round((0.9198-0.5)/0.9198 * 100, 2)
# Out:
# 45.64

# %% [markdown]
# Observations
#
# - The performance of the model with the test data remained at 89 indicating no potential overfitting.
# - The sanity check indicates that our model of choice performed 45\% better than out dummy classifier.

# %% [markdown]
# # Conclusion
#
# In terms of services, most Interconnect churned customers are associated with:
#
# - month-to-month types of contract,
# - paperless billing,
# - electronic checks type of payment,
# - fiber optic internet service,
# - no online security,
# - no backup support,
# - no device protection,
# - no tech support,
# - 1 to 3 total services,
#
# In terms of trends,
#
# - The last months of the year seem most associated with churning
# - Midweek (Wednesday and Thursday) and Saturdays are most associated with churning.
#
# In terms of income,
# - The mean monthly charges of those who churned is around 18% higher than those customers who are still active.
# - The bulk of those who churned seems to increase as monthly charges increase.  In may 2019, churning increases gradually to reach a peak in September.
# - The mean total charges for those who churned is 40\% less that those who are still active.  Over time, the total charges of active accounts is decreasing.  However, the total charges of those who churned seem t be more volatile
# - Churning seems associated with overall lower days of service.  The mean days_of_service for those who churned is half that of those who are still active.  In mid 2018, there seems to be a spike in the days_of_service of those who churned.  Although this surge is attenuated, it does not go back to its pre 2018 levels.  In fact, this surge peaked in January 2019, but has since decreased.
# - Churning has been increasing every year and reaches its peak in 2019, but then drops
#
#
# Based on these observations and the modeling, Interconnect's marketing teams should:
#
# - introduce end of year promotions to entice customers to remain active.
# - introduce games or draws to keep customers engaged on Wednesdays and Saturdays.
# - gradually remove the month-to-month type of service
# - since those who are going paperless and paying by electronic checks are churning, introduce more environmentally friendly services
# - study the monthly charges of those who churned. The variance of those monthly bills need to become smoother.  more specifically target those customers with higher bills.
#
# The team should be heartened that the churning trend is declining and should work on keeping this trend going to stabilize churning over time.
